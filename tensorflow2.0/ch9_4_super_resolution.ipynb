# %% [markdown]
# <a href="https://colab.research.google.com/github/chloevan/deeplearningAI/blob/master/tensorflow2.0/ch9_4_super_resolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# title: "Tensorflow 2.0 Tutorial ch9.4 - 초해상도"
# date: 2020-05-04T17:20:30+09:00
# tags:
#   - "Deep Learning"
#   - "Python"
#   - "Google Colab"
#   - "Tensorflow 2.0"
#   - "Binary Classification"
#   - "Classification"
#   - "오토인코더"
#   - "Auto Encoder"
#   - "초해상도"
#   - "Super Resolution"
#   - "Clustering"
#   - "텐서플로 2.0"
#   - "텐서플로 2.0 튜토리얼"
#   - "Tensorflow 2.0 Tutorial"
# categories:
#   - "Deep Learning"
#   - "딥러닝"
#   - "텐서플로 2.0"
#   - "Python"
#   - "Tensorflow 2.0"
#   - "텐서플로 2.0 튜토리얼"
#   - "Tensorflow 2.0 Tutorial"
# menu:
#   python:
#     name: Tensorflow 2.0 Tutorial ch9.4 - 초해상도
# ---
#
# ## 공지
#
# - 본 Tutorial은 교재 `시작하세요 텐서플로 2.0 프로그래밍`의 강사에게 국비교육 강의를 듣는 사람들에게 자료 제공을 목적으로 제작하였습니다.
#
# - 강사의 주관적인 판단으로 압축해서 자료를 정리하였기 때문에, 자세하게 공부를 하고 싶으신 분은 반드시 교재를 구매하실 것을 권해드립니다.
#
# ![](/img/tensorflow2.0/book.jpg)<!-- -->
#
#
# - 본 교재 외에 강사가 추가한 내용에 대한 Reference를 확인하셔서, 추가적으로 학습하시는 것을 권유드립니다.
#
#
# ## Tutorial
#
# 이전 강의가 궁금하신 분들은 아래에서 선택하여 추가 학습 하시기를 바랍니다.
#
# - [Google Colab Tensorflow 2.0 Installation](https://chloevan.github.io/python/tensorflow2.0/googlecolab/)
# - [Tensorflow 2.0 Tutorial ch3.3.1 - 난수 생성 및 시그모이드 함수](https://chloevan.github.io/python/tensorflow2.0/ch3_3_1_random_signoid/)
# - [Tensorflow 2.0 Tutorial ch3.3.2 - 난수 생성 및 시그모이드 함수 편향성](https://chloevan.github.io/python/tensorflow2.0/ch3_3_2_random_signoid_bias/)
# - [Tensorflow 2.0 Tutorial ch3.3.3 - 첫번째 신경망 네트워크 - AND](https://chloevan.github.io/python/tensorflow2.0/ch3_3_3_network_and/)
# - [Tensorflow 2.0 Tutorial ch3.3.4 - 두번째 신경망 네트워크 - OR](https://chloevan.github.io/python/tensorflow2.0/ch3_3_4_network_or/)
# - [Tensorflow 2.0 Tutorial ch3.3.5 - 세번째 신경망 네트워크 - XOR](https://chloevan.github.io/python/tensorflow2.0/ch3_3_5_network_xor/)
# - [Tensorflow 2.0 Tutorial ch4.1 - 선형회귀](https://chloevan.github.io/python/tensorflow2.0/ch4_1_linear_regression/)
# - [Tensorflow 2.0 Tutorial ch4.2 - 다항회귀](https://chloevan.github.io/python/tensorflow2.0/ch4_2_multiple_linear_regression/)
# - [Tensorflow 2.0 Tutorial ch4.3 - 딥러닝 네트워크를 이용한 회귀](https://chloevan.github.io/python/tensorflow2.0/ch4_3_regression_with_deeplearning/)
# - [Tensorflow 2.0 Tutorial ch4.4 - 보스턴 주택 가격 데이터세트](https://chloevan.github.io/python/tensorflow2.0/ch4_4_boston_housing_deeplearning/)
# - [Tensorflow 2.0 Tutorial ch5.1 - 분류](https://chloevan.github.io/python/tensorflow2.0/ch5_1_binary_classification/)
# - [Tensorflow 2.0 Tutorial ch5.2 - 다항분류](https://chloevan.github.io/python/tensorflow2.0/ch5_2_multi_classification/)
# - [Tensorflow 2.0 Tutorial ch5.3 - Fashion MNIST](https://chloevan.github.io/python/tensorflow2.0/ch5_3_fashion_mnist/)
# - [Tensorflow 2.0 Tutorial ch6.1-2 - CNN 이론](https://chloevan.github.io/python/tensorflow2.0/ch6_1_2_cnn_theory/)
# - [Tensorflow 2.0 Tutorial ch6.3 - Fashion MNIST with CNN 실습](https://chloevan.github.io/python/tensorflow2.0/ch6_3_fashion_mnist_with_cnn/)
# - [Tensorflow 2.0 Tutorial ch6.4 - 모형의 성능 높이기](https://chloevan.github.io/python/tensorflow2.0/ch6_4_improve_performance/)
# - [Tensorflow 2.0 Tutorial ch7.1 - RNN 이론 (1)](https://chloevan.github.io/python/tensorflow2.0/ch7_1_2_rnn_theory1/)
# - [Tensorflow 2.0 Tutorial ch7.1 - RNN 이론 (2)](https://chloevan.github.io/python/tensorflow2.0/ch7_1_2_rnn_theory2/)
# - [Tensorflow 2.0 Tutorial ch7.3 - 긍정, 부정 감성 분석](https://chloevan.github.io/python/tensorflow2.0/ch7_3_sentimentanalysis/)
# - [Tensorflow 2.0 Tutorial ch7.4 - (1) 단어 단위 생성](https://chloevan.github.io/python/tensorflow2.0/ch7_4_naturallanguagegeneration1/)
# - [Tensorflow 2.0 Tutorial ch7.4 - (2) 단어 단위 생성](https://chloevan.github.io/python/tensorflow2.0/ch7_4_naturallanguagegeneration2/)
# - [Tensorflow 2.0 Tutorial ch8.1 - 텐서플로 허브](https://chloevan.github.io/python/tensorflow2.0/ch8_1_tensorflow_hub/)
# - [Tensorflow 2.0 Tutorial ch8.2 - 전이 학습과 & Kaggle 대회](https://chloevan.github.io/python/tensorflow2.0/ch8_2_transfer_learning/)
# - [Tensorflow 2.0 Tutorial ch8.3.1 - 컨볼루션 신경망을 사용한 텍스처 합성](https://chloevan.github.io/python/tensorflow2.0/ch8_3_1_texture_synthesis/)
# - [Tensorflow 2.0 Tutorial ch8.3.2 - 컨볼루션 신경망을 사용한 신경 스타일 전이](https://chloevan.github.io/python/tensorflow2.0/ch8_3_2_neural_style_transfer/)
# - [Tensorflow 2.0 Tutorial ch9.1-2 - 오토인코더 & MNIST](https://chloevan.github.io/python/tensorflow2.0/ch9_1_auto_encoder/)
# - [Tensorflow 2.0 Tutorial ch9.3 - 클러스터링](https://chloevan.github.io/python/tensorflow2.0/ch9_3_k_means_clustering/)

# %% [markdown]
# ## I. 개요
#
# - 저해상도에서 고해상도의 이미지로 변환하는 것은 어려운 연산입니다.
# - 픽셀로 구성된 이미지는 고해상도로 변환(확대)하면 이미지에서 사각형이 두드러져 보이는 것이 바로 초해상도(`Super Resolution`) 작업입니다.
# - 전통적으로는 `interpolation(보간)` 등의 기법이 있지만, 선명함을 잃고 흐릿해지는 단점이 있습니다.
# - 오토인코더로 초해상도 작업을 하는 과정을 진행합니다.
# - 이 때, `REDNet`이라는 네트워크를 사용합니다.

# %% [markdown]
# ## II. REDNet[^1]
#
# - `REDNet`은 `Residual Encoder-Decoder Network`의 약자이며, `Residual`은 `ResNet`등에서 사용하는 건너뛴 연결(`skip-connection`)입니다.
# - 다수의 레이어가 중첩되는 구조에서 앞쪽의 정보를 잃어버리기 않기 위해 뒤쪽에 정보를 그대로 전달해줄 때 건너뛴 연결이 사용됩니다.
# - 논문에서 사용한 이미지는 `BSD (Berkeley Segmentation Dataset)` 이며, 책에서도 동일하게 사용합니다.

# %%
# 텐서플로 2 버전 선택
try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
except Exception:
    pass
import tensorflow as tf
import numpy as np
import pandas as pd
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## III. 데이터 불러오기
# - `tf.keras.utils.get_file()` 데이터를 불러옵니다.

# %%
tf.keras.utils.get_file('/content/bsd_images.zip', 'http://bit.ly/35pHZlC', extract=True)
# Out:
# Downloading data from http://bit.ly/35pHZlC
# 37527552/37520292 [==============================] - 0s 0us/step
# '/content/bsd_images.zip'

# %%
# !unzip /content/bsd_images.zip
# Out:
# Archive:  /content/bsd_images.zip
#    creating: images/
#    creating: images/test/
#   inflating: images/test/100007.jpg
#   inflating: images/test/100039.jpg
#   inflating: images/test/100099.jpg
#   inflating: images/test/10081.jpg
#   inflating: images/test/101027.jpg
#   inflating: images/test/101084.jpg
#   inflating: images/test/102062.jpg
#   inflating: images/test/103006.jpg
#   inflating: images/test/103029.jpg
#   inflating: images/test/103078.jpg
#   inflating: images/test/104010.jpg
#   inflating: images/test/104055.jpg
#   inflating: images/test/105027.jpg
#   inflating: images/test/106005.jpg
#   inflating: images/test/106047.jpg
#   inflating: images/test/107014.jpg
#   inflating: images/test/107045.jpg
#   inflating: images/test/107072.jpg
#   inflating: images/test/108004.jpg
#   inflating: images/test/108036.jpg
#   inflating: images/test/108069.jpg
#   inflating: images/test/109055.jpg
#   inflating: images/test/112056.jpg
#   inflating: images/test/112090.jpg
#   inflating: images/test/117025.jpg
#   inflating: images/test/118015.jpg
#   inflating: images/test/118031.jpg
#   inflating: images/test/118072.jpg
#   inflating: images/test/120003.jpg
#   inflating: images/test/120093.jpg
#   inflating: images/test/123057.jpg
#   inflating: images/test/128035.jpg
#   inflating: images/test/130014.jpg
#   inflating: images/test/130066.jpg
#   inflating: images/test/134049.jpg
#   inflating: images/test/134067.jpg
#   inflating: images/test/140006.jpg
#   inflating: images/test/140088.jpg
#   inflating: images/test/14085.jpg
#   inflating: images/test/14092.jpg
#   inflating: images/test/141012.jpg
#   inflating: images/test/141048.jpg
#   inflating: images/test/145059.jpg
#   inflating: images/test/145079.jpg
#   inflating: images/test/146074.jpg
#   inflating: images/test/147077.jpg
#   inflating: images/test/147080.jpg
#   inflating: images/test/15011.jpg
#   inflating: images/test/15062.jpg
#   inflating: images/test/156054.jpg
#   inflating: images/test/157032.jpg
#   inflating: images/test/157087.jpg
#   inflating: images/test/159002.jpg
#   inflating: images/test/159022.jpg
#   inflating: images/test/160006.jpg
#   inflating: images/test/16004.jpg
#   inflating: images/test/160067.jpg
#   inflating: images/test/16068.jpg
#   inflating: images/test/161045.jpg
#   inflating: images/test/163004.jpg
#   inflating: images/test/163096.jpg
#   inflating: images/test/164046.jpg
#   inflating: images/test/168084.jpg
#   inflating: images/test/17067.jpg
#   inflating: images/test/175083.jpg
#   inflating: images/test/176051.jpg
#   inflating: images/test/179084.jpg
#   inflating: images/test/181021.jpg
#   inflating: images/test/183066.jpg
#   inflating: images/test/185092.jpg
#   inflating: images/test/187058.jpg
#   inflating: images/test/187099.jpg
#   inflating: images/test/188025.jpg
#   inflating: images/test/189006.jpg
#   inflating: images/test/189013.jpg
#   inflating: images/test/189029.jpg
#   inflating: images/test/189096.jpg
#   inflating: images/test/196027.jpg
#   inflating: images/test/196040.jpg
#   inflating: images/test/196062.jpg
#   inflating: images/test/196088.jpg
#   inflating: images/test/198087.jpg
#   inflating: images/test/20069.jpg
#   inflating: images/test/201080.jpg
#   inflating: images/test/2018.jpg
#   inflating: images/test/202000.jpg
#   inflating: images/test/206062.jpg
#   inflating: images/test/206097.jpg
#   inflating: images/test/207038.jpg
#   inflating: images/test/207049.jpg
#   inflating: images/test/208078.jpg
#   inflating: images/test/209021.jpg
#   inflating: images/test/217013.jpg
#   inflating: images/test/217090.jpg
#   inflating: images/test/220003.jpg
#   inflating: images/test/223004.jpg
#   inflating: images/test/223060.jpg
#   inflating: images/test/225022.jpg
#   inflating: images/test/226022.jpg
#   inflating: images/test/226033.jpg
#   inflating: images/test/226043.jpg
#   inflating: images/test/226060.jpg
#   inflating: images/test/228076.jpg
#   inflating: images/test/230063.jpg
#   inflating: images/test/230098.jpg
#   inflating: images/test/23050.jpg
#   inflating: images/test/232076.jpg
#   inflating: images/test/235098.jpg
#   inflating: images/test/238025.jpg
#   inflating: images/test/243095.jpg
#   inflating: images/test/246009.jpg
#   inflating: images/test/247003.jpg
#   inflating: images/test/247012.jpg
#   inflating: images/test/249021.jpg
#   inflating: images/test/250047.jpg
#   inflating: images/test/250087.jpg
#   inflating: images/test/253016.jpg
#   inflating: images/test/253092.jpg
#   inflating: images/test/257098.jpg
#   inflating: images/test/258089.jpg
#   inflating: images/test/259060.jpg
#   inflating: images/test/267036.jpg
#   inflating: images/test/268048.jpg
#   inflating: images/test/268074.jpg
#   inflating: images/test/277053.jpg
#   inflating: images/test/279005.jpg
#   inflating: images/test/28083.jpg
#   inflating: images/test/281017.jpg
#   inflating: images/test/285022.jpg
#   inflating: images/test/288024.jpg
#   inflating: images/test/289011.jpg
#   inflating: images/test/290035.jpg
#   inflating: images/test/29030.jpg
#   inflating: images/test/296028.jpg
#   inflating: images/test/296058.jpg
#   inflating: images/test/302022.jpg
#   inflating: images/test/306051.jpg
#   inflating: images/test/306052.jpg
#   inflating: images/test/3063.jpg
#   inflating: images/test/309040.jpg
#   inflating: images/test/317043.jpg
#   inflating: images/test/326025.jpg
#   inflating: images/test/326085.jpg
#   inflating: images/test/33044.jpg
#   inflating: images/test/334025.jpg
#   inflating: images/test/335088.jpg
#   inflating: images/test/335094.jpg
#   inflating: images/test/344010.jpg
#   inflating: images/test/346016.jpg
#   inflating: images/test/347031.jpg
#   inflating: images/test/35028.jpg
#   inflating: images/test/35049.jpg
#   inflating: images/test/36046.jpg
#   inflating: images/test/365072.jpg
#   inflating: images/test/368037.jpg
#   inflating: images/test/372019.jpg
#   inflating: images/test/376086.jpg
#   inflating: images/test/384022.jpg
#   inflating: images/test/384089.jpg
#   inflating: images/test/385022.jpg
#   inflating: images/test/388006.jpg
#   inflating: images/test/388018.jpg
#   inflating: images/test/388067.jpg
#   inflating: images/test/393035.jpg
#   inflating: images/test/41006.jpg
#   inflating: images/test/41029.jpg
#   inflating: images/test/41085.jpg
#   inflating: images/test/41096.jpg
#   inflating: images/test/43033.jpg
#   inflating: images/test/43051.jpg
#   inflating: images/test/45000.jpg
#   inflating: images/test/48017.jpg
#   inflating: images/test/48025.jpg
#   inflating: images/test/49024.jpg
#   inflating: images/test/5096.jpg
#   inflating: images/test/51084.jpg
#   inflating: images/test/6046.jpg
#   inflating: images/test/61034.jpg
#   inflating: images/test/64061.jpg
#   inflating: images/test/65084.jpg
#   inflating: images/test/69000.jpg
#   inflating: images/test/69007.jpg
#   inflating: images/test/69022.jpg
#   inflating: images/test/70011.jpg
#   inflating: images/test/70090.jpg
#   inflating: images/test/71076.jpg
#   inflating: images/test/71099.jpg
#   inflating: images/test/77062.jpg
#   inflating: images/test/78098.jpg
#   inflating: images/test/79073.jpg
#   inflating: images/test/80085.jpg
#   inflating: images/test/80090.jpg
#   inflating: images/test/8068.jpg
#   inflating: images/test/81066.jpg
#   inflating: images/test/81090.jpg
#   inflating: images/test/81095.jpg
#   inflating: images/test/87015.jpg
#   inflating: images/test/92014.jpg
#   inflating: images/test/94095.jpg
#   inflating: images/test/97010.jpg
#   inflating: images/test/Thumbs.db
#    creating: images/train/
#   inflating: images/train/100075.jpg
#   inflating: images/train/100080.jpg
#   inflating: images/train/100098.jpg
#   inflating: images/train/103041.jpg
#   inflating: images/train/104022.jpg
#   inflating: images/train/105019.jpg
#   inflating: images/train/105053.jpg
#   inflating: images/train/106020.jpg
#   inflating: images/train/106025.jpg
#   inflating: images/train/108041.jpg
#   inflating: images/train/108073.jpg
#   inflating: images/train/109034.jpg
#   inflating: images/train/112082.jpg
#   inflating: images/train/113009.jpg
#   inflating: images/train/113016.jpg
#   inflating: images/train/113044.jpg
#   inflating: images/train/117054.jpg
#   inflating: images/train/118020.jpg
#   inflating: images/train/118035.jpg
#   inflating: images/train/12003.jpg
#   inflating: images/train/12074.jpg
#   inflating: images/train/122048.jpg
#   inflating: images/train/124084.jpg
#   inflating: images/train/126039.jpg
#   inflating: images/train/130034.jpg
#   inflating: images/train/134008.jpg
#   inflating: images/train/134052.jpg
#   inflating: images/train/135037.jpg
#   inflating: images/train/135069.jpg
#   inflating: images/train/138032.jpg
#   inflating: images/train/138078.jpg
#   inflating: images/train/140055.jpg
#   inflating: images/train/140075.jpg
#   inflating: images/train/144067.jpg
#   inflating: images/train/145014.jpg
#   inflating: images/train/145053.jpg
#   inflating: images/train/147021.jpg
#   inflating: images/train/147062.jpg
#   inflating: images/train/15004.jpg
#   inflating: images/train/15088.jpg
#   inflating: images/train/151087.jpg
#   inflating: images/train/153077.jpg
#   inflating: images/train/153093.jpg
#   inflating: images/train/155060.jpg
#   inflating: images/train/156079.jpg
#   inflating: images/train/157036.jpg
#   inflating: images/train/159029.jpg
#   inflating: images/train/159045.jpg
#   inflating: images/train/159091.jpg
#   inflating: images/train/16052.jpg
#   inflating: images/train/161062.jpg
#   inflating: images/train/163014.jpg
#   inflating: images/train/163062.jpg
#   inflating: images/train/164074.jpg
#   inflating: images/train/166081.jpg
#   inflating: images/train/169012.jpg
#   inflating: images/train/170054.jpg
#   inflating: images/train/172032.jpg
#   inflating: images/train/173036.jpg
#   inflating: images/train/176019.jpg
#   inflating: images/train/176035.jpg
#   inflating: images/train/176039.jpg
#   inflating: images/train/178054.jpg
#   inflating: images/train/181018.jpg
#   inflating: images/train/181079.jpg
#   inflating: images/train/181091.jpg
#   inflating: images/train/183055.jpg
#   inflating: images/train/183087.jpg
#   inflating: images/train/187003.jpg
#   inflating: images/train/187029.jpg
#   inflating: images/train/187039.jpg
#   inflating: images/train/187071.jpg
#   inflating: images/train/187083.jpg
#   inflating: images/train/188005.jpg
#   inflating: images/train/188063.jpg
#   inflating: images/train/188091.jpg
#   inflating: images/train/189003.jpg
#   inflating: images/train/189011.jpg
#   inflating: images/train/196015.jpg
#   inflating: images/train/198004.jpg
#   inflating: images/train/198023.jpg
#   inflating: images/train/198054.jpg
#   inflating: images/train/20008.jpg
#   inflating: images/train/202012.jpg
#   inflating: images/train/207056.jpg
#   inflating: images/train/209070.jpg
#   inflating: images/train/2092.jpg
#   inflating: images/train/216041.jpg
#   inflating: images/train/216053.jpg
#   inflating: images/train/216066.jpg
#   inflating: images/train/22013.jpg
#   inflating: images/train/22090.jpg
#   inflating: images/train/22093.jpg
#   inflating: images/train/225017.jpg
#   inflating: images/train/227040.jpg
#   inflating: images/train/227046.jpg
#   inflating: images/train/23025.jpg
#   inflating: images/train/23080.jpg
#   inflating: images/train/23084.jpg
#   inflating: images/train/231015.jpg
#   inflating: images/train/232038.jpg
#   inflating: images/train/236017.jpg
#   inflating: images/train/238011.jpg
#   inflating: images/train/239007.jpg
#   inflating: images/train/239096.jpg
#   inflating: images/train/24004.jpg
#   inflating: images/train/24063.jpg
#   inflating: images/train/242078.jpg
#   inflating: images/train/245051.jpg
#   inflating: images/train/246016.jpg
#   inflating: images/train/246053.jpg
#   inflating: images/train/247085.jpg
#   inflating: images/train/249061.jpg
#   inflating: images/train/249087.jpg
#   inflating: images/train/25098.jpg
#   inflating: images/train/253036.jpg
#   inflating: images/train/254033.jpg
#   inflating: images/train/254054.jpg
#   inflating: images/train/260081.jpg
#   inflating: images/train/26031.jpg
#   inflating: images/train/268002.jpg
#   inflating: images/train/27059.jpg
#   inflating: images/train/271008.jpg
#   inflating: images/train/271031.jpg
#   inflating: images/train/274007.jpg
#   inflating: images/train/277095.jpg
#   inflating: images/train/28075.jpg
#   inflating: images/train/28096.jpg
#   inflating: images/train/285036.jpg
#   inflating: images/train/286092.jpg
#   inflating: images/train/292066.jpg
#   inflating: images/train/293029.jpg
#   inflating: images/train/299091.jpg
#   inflating: images/train/301007.jpg
#   inflating: images/train/302003.jpg
#   inflating: images/train/309004.jpg
#   inflating: images/train/310007.jpg
#   inflating: images/train/311068.jpg
#   inflating: images/train/311081.jpg
#   inflating: images/train/314016.jpg
#   inflating: images/train/317080.jpg
#   inflating: images/train/323016.jpg
#   inflating: images/train/326038.jpg
#   inflating: images/train/33066.jpg
#   inflating: images/train/35008.jpg
#   inflating: images/train/35010.jpg
#   inflating: images/train/35058.jpg
#   inflating: images/train/35070.jpg
#   inflating: images/train/35091.jpg
#   inflating: images/train/353013.jpg
#   inflating: images/train/361084.jpg
#   inflating: images/train/365025.jpg
#   inflating: images/train/365073.jpg
#   inflating: images/train/368016.jpg
#   inflating: images/train/368078.jpg
#   inflating: images/train/370036.jpg
#   inflating: images/train/372047.jpg
#   inflating: images/train/374020.jpg
#   inflating: images/train/374067.jpg
#   inflating: images/train/376001.jpg
#   inflating: images/train/376020.jpg
#   inflating: images/train/385028.jpg
#   inflating: images/train/388016.jpg
#   inflating: images/train/41004.jpg
#   inflating: images/train/41025.jpg
#   inflating: images/train/42044.jpg
#   inflating: images/train/42078.jpg
#   inflating: images/train/43070.jpg
#   inflating: images/train/43083.jpg
#   inflating: images/train/45077.jpg
#   inflating: images/train/46076.jpg
#   inflating: images/train/48055.jpg
#   inflating: images/train/54005.jpg
#   inflating: images/train/55067.jpg
#   inflating: images/train/55075.jpg
#   inflating: images/train/56028.jpg
#   inflating: images/train/59078.jpg
#   inflating: images/train/60079.jpg
#   inflating: images/train/61060.jpg
#   inflating: images/train/61086.jpg
#   inflating: images/train/65010.jpg
#   inflating: images/train/65019.jpg
#   inflating: images/train/65074.jpg
#   inflating: images/train/65132.jpg
#   inflating: images/train/66039.jpg
#   inflating: images/train/66075.jpg
#   inflating: images/train/67079.jpg
#   inflating: images/train/68077.jpg
#   inflating: images/train/71046.jpg
#   inflating: images/train/76002.jpg
#   inflating: images/train/78019.jpg
#   inflating: images/train/80099.jpg
#   inflating: images/train/8049.jpg
#   inflating: images/train/8143.jpg
#   inflating: images/train/87065.jpg
#   inflating: images/train/90076.jpg
#   inflating: images/train/92059.jpg
#   inflating: images/train/94079.jpg
#   inflating: images/train/95006.jpg
#   inflating: images/train/97017.jpg
#   inflating: images/train/Thumbs.db
#    creating: images/val/
#   inflating: images/val/101085.jpg
#   inflating: images/val/101087.jpg
#   inflating: images/val/102061.jpg
#   inflating: images/val/103070.jpg
#   inflating: images/val/105025.jpg
#   inflating: images/val/106024.jpg
#   inflating: images/val/108005.jpg
#   inflating: images/val/108070.jpg
#   inflating: images/val/108082.jpg
#   inflating: images/val/109053.jpg
#   inflating: images/val/119082.jpg
#   inflating: images/val/12084.jpg
#   inflating: images/val/123074.jpg
#   inflating: images/val/126007.jpg
#   inflating: images/val/130026.jpg
#   inflating: images/val/134035.jpg
#   inflating: images/val/14037.jpg
#   inflating: images/val/143090.jpg
#   inflating: images/val/145086.jpg
#   inflating: images/val/147091.jpg
#   inflating: images/val/148026.jpg
#   inflating: images/val/148089.jpg
#   inflating: images/val/156065.jpg
#   inflating: images/val/157055.jpg
#   inflating: images/val/159008.jpg
#   inflating: images/val/160068.jpg
#   inflating: images/val/16077.jpg
#   inflating: images/val/163085.jpg
#   inflating: images/val/167062.jpg
#   inflating: images/val/167083.jpg
#   inflating: images/val/170057.jpg
#   inflating: images/val/175032.jpg
#   inflating: images/val/175043.jpg
#   inflating: images/val/182053.jpg
#   inflating: images/val/189080.jpg
#   inflating: images/val/19021.jpg
#   inflating: images/val/196073.jpg
#   inflating: images/val/197017.jpg
#   inflating: images/val/208001.jpg
#   inflating: images/val/210088.jpg
#   inflating: images/val/21077.jpg
#   inflating: images/val/216081.jpg
#   inflating: images/val/219090.jpg
#   inflating: images/val/220075.jpg
#   inflating: images/val/223061.jpg
#   inflating: images/val/227092.jpg
#   inflating: images/val/229036.jpg
#   inflating: images/val/236037.jpg
#   inflating: images/val/24077.jpg
#   inflating: images/val/241004.jpg
#   inflating: images/val/241048.jpg
#   inflating: images/val/253027.jpg
#   inflating: images/val/253055.jpg
#   inflating: images/val/260058.jpg
#   inflating: images/val/271035.jpg
#   inflating: images/val/285079.jpg
#   inflating: images/val/291000.jpg
#   inflating: images/val/295087.jpg
#   inflating: images/val/296007.jpg
#   inflating: images/val/296059.jpg
#   inflating: images/val/299086.jpg
#   inflating: images/val/300091.jpg
#   inflating: images/val/302008.jpg
#   inflating: images/val/304034.jpg
#   inflating: images/val/304074.jpg
#   inflating: images/val/306005.jpg
#   inflating: images/val/3096.jpg
#   inflating: images/val/33039.jpg
#   inflating: images/val/351093.jpg
#   inflating: images/val/361010.jpg
#   inflating: images/val/37073.jpg
#   inflating: images/val/376043.jpg
#   inflating: images/val/38082.jpg
#   inflating: images/val/38092.jpg
#   inflating: images/val/385039.jpg
#   inflating: images/val/41033.jpg
#   inflating: images/val/41069.jpg
#   inflating: images/val/42012.jpg
#   inflating: images/val/42049.jpg
#   inflating: images/val/43074.jpg
#   inflating: images/val/45096.jpg
#   inflating: images/val/54082.jpg
#   inflating: images/val/55073.jpg
#   inflating: images/val/58060.jpg
#   inflating: images/val/62096.jpg
#   inflating: images/val/65033.jpg
#   inflating: images/val/66053.jpg
#   inflating: images/val/69015.jpg
#   inflating: images/val/69020.jpg
#   inflating: images/val/69040.jpg
#   inflating: images/val/76053.jpg
#   inflating: images/val/78004.jpg
#   inflating: images/val/8023.jpg
#   inflating: images/val/85048.jpg
#   inflating: images/val/86000.jpg
#   inflating: images/val/86016.jpg
#   inflating: images/val/86068.jpg
#   inflating: images/val/87046.jpg
#   inflating: images/val/89072.jpg
#   inflating: images/val/97033.jpg
#   inflating: images/val/Thumbs.db

# %% [markdown]
# - 이미지 경로 저장 및 확인을 합니다.

# %%
import pathlib
image_root = pathlib.Path('/content/images')
all_images_paths=list(image_root.glob('*/*'))
print(all_images_paths[:10])
# Out:
# [PosixPath('/content/images/val/62096.jpg'), PosixPath('/content/images/val/361010.jpg'), PosixPath('/content/images/val/Thumbs.db'), PosixPath('/content/images/val/54082.jpg'), PosixPath('/content/images/val/87046.jpg'), PosixPath('/content/images/val/38082.jpg'), PosixPath('/content/images/val/156065.jpg'), PosixPath('/content/images/val/33039.jpg'), PosixPath('/content/images/val/14037.jpg'), PosixPath('/content/images/val/159008.jpg')]

# %% [markdown]
# - 각 이미지의 경로는 `root` 디렉터리에서 `glob()` 함수를 사용해 하단의 모든 파일을 불러올 수 있습니다.
# - 각 파일의 경로는 `PosixPath`라는 객체가 되는데, 이 객체에서 경로를 가져오기 위해서는 문자열로 변환하는 `str()`함수를 사용합니다.

# %% [markdown]
# ### (1) 이미지 시각화
# - `matplotlib.pyplot`으로 확인합니다.

# %%
import PIL.Image as Image
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))
for c in range(9):
  plt.subplot(3,3,c+1)
  plt.imshow(plt.imread(all_images_paths[c]))
  plt.title(all_images_paths[c])
  plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-8-7f6df2e4a3bd> in <module>()
#       5 for c in range(9):
#       6   plt.subplot(3,3,c+1)
# ----> 7   plt.imshow(plt.imread(all_images_paths[c]))
#       8   plt.title(all_images_paths[c])
#       9   plt.axis('off')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imread(fname, format)
#    2059 @docstring.copy(matplotlib.image.imread)
#    2060 def imread(fname, format=None):
# -> 2061     return matplotlib.image.imread(fname, format)
#    2062
#    2063
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in imread(fname, format)
#    1462             raise ValueError('Only know how to handle PNG; with Pillow '
#    1463                              'installed, Matplotlib can handle more images')
# -> 1464         with Image.open(fname) as image:
#    1465             return pil_to_array(image)
#    1466     from matplotlib import _png
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2860         warnings.warn(message)
#    2861     raise UnidentifiedImageError(
# -> 2862         "cannot identify image file %r" % (filename if filename else fp)
#    2863     )
#    2864
#
# UnidentifiedImageError: cannot identify image file '/content/images/val/Thumbs.db'

# %% [markdown]
# - 데이터를 보면 아시겠지만, 가로와 세로 길이가 모두 다릅니다. 또한, 이미지의 내용은 사람, 동물, 자연등으로 다양합니다.

# %% [markdown]
# ### (2) 이미지 경로 분리 저장
# - `BSD500`은 200장의 훈련 데이터, 100장의 검증 데이터, 200장의 테스트 데이터로 구성되어 있습니다.
# - `tf.data.Dataset`를 각 데이터세트마다 만듭니다.

# %%
train_path, valid_path, test_path = [], [], []

for image_path in all_images_paths:
  if str(image_path).split('.')[-1] != "jpg":
    continue
  
  if str(image_path).split('/')[-2]== 'train': 
    train_path.append(str(image_path))
  elif str(image_path).split('/')[-2]=='val':
    valid_path.append(str(image_path))
  else:
    test_path.append(str(image_path))

# %% [markdown]
# ### (3) 원본 이미지 조각 추출, 입력, 출력 데이터 변환 함수 정의
# - 현재의 이미지는 고해상도이기 때문에, 저해상도는 일부러 낮추고 원본과 함께 반환하는 함수를 만듭니다.
# - 원본 이미지에서 조각을 추출해서 입력, 출력 데이터를 생성하는 구조에 관한 이미지는 교재 360페이지를 확인해봅니다.

# %%
def get_hr_and_lr(image_path):
  img = tf.io.read_file(image_path)
  img = tf.image.decode_jpeg(img, channels=3)
  img = tf.image.convert_image_dtype(img, tf.float32)

  hr = tf.image.random_crop(img, [50,50,3])
  lr = tf.image.resize(hr, [25, 25])
  lr = tf.image.resize(lr, [50,50])

  return lr, hr

# %% [markdown]
# - `JPEG` 이미지는 `tf.io.read_file()`로 불러올 수 있습니다.
# - 이미지를 불러온 후 `decode_jpeg()` 함수를 사용해서 프로그램이 이해할 수 있는 데이터 형태로 만들어야 하고, `convert_image_dtype()`함수로 데이터 타입을 딥러닝에서 가장 범용적으로 사용하는 `float32` 데이터 타입으로 바꿉니다.
# - 가로 X 세로 50픽셀의 이미지를 `random_crop()`이라는 함수로 쉽게 얻을 수 있습니다.
# - 마지막의 3은 컬러 채널의 수를 의미합니다.

# %% [markdown]
# ### (4) `train, valid Dataset 정의`
#
# - `Dataset`를 정의할 차례이며, 학습 과정에서 사용할 훈련 데이터와 검증 데이터를 사용하는 `Dataset`를 각각 정의합니다.

# %%
train_dataset = tf.data.Dataset.list_files(train_path)
train_dataset = train_dataset.map(get_hr_and_lr)
train_dataset = train_dataset.repeat()
train_dataset = train_dataset.batch(16)

valid_dataset = tf.data.Dataset.list_files(train_path)
valid_dataset = valid_dataset.map(get_hr_and_lr)
valid_dataset = valid_dataset.repeat()
valid_dataset = valid_dataset.batch(1)

# %% [markdown]
# - 먼저 파일의 경로 리스트를 가지고 있다면 `tf.data.Dataset.list_files()` 함수의 인수로 파일 경로 리스트를 넣어서 `Dataset`를 쉽게 정의할 수 있습니다.
# - `get_hr_and_lr()` 함수를 `map()`함수를 적용해 새로운 `Dataset`을 만듭니다.
# - 이렇게 연결되면 `Dataset`는 먼저 `train_path` 리스트의 이미지를 불러온 다음에 저해상도와 고해상도 조각인 `lr`, `hr`을 반환합니다. 여기까지 선언하면 쉽게 사용할 수 있는 `Dataset`을 1차로 완성한 것입니다.

# %% [markdown]
# ### (5) REDNet-30의 정의
# `REDNet-30`에 대한 구조에 대한 설명은 교재 `362-363 p`를 확인합니다. 다음 소스코드로 네트워크 정의를 합니다.

# %%
def REDNet(num_layers):
    conv_layers = []
    deconv_layers = []
    residual_layers = []

    inputs = tf.keras.layers.Input(shape=(None, None, 3))
    conv_layers.append(tf.keras.layers.Conv2D(3, kernel_size=3, padding='same', activation='relu'))

    for i in range(num_layers-1):
        conv_layers.append(tf.keras.layers.Conv2D(64, kernel_size=3, padding='same', activation='relu'))
        deconv_layers.append(tf.keras.layers.Conv2DTranspose(64, kernel_size=3, padding='same', activation='relu'))

    deconv_layers.append(tf.keras.layers.Conv2DTranspose(3, kernel_size=3, padding='same'))

    # 인코더 시작
    x = conv_layers[0](inputs)

    for i in range(num_layers-1):
        x = conv_layers[i+1](x)
        if i % 2 == 0:
            residual_layers.append(x)

    # 디코더 시작
    for i in range(num_layers-1):
        if i % 2 == 1:
            x = tf.keras.layers.Add()([x, residual_layers.pop()])
            x = tf.keras.layers.Activation('relu')(x)
        x = deconv_layers[i](x) 

    x = deconv_layers[-1](x)
    
    model = tf.keras.Model(inputs=inputs, outputs=x)
    return model

# %% [markdown]
# - 위 함수를 통해서, `REDNet-10, REDNet-20, REDNet-30`등 다양한 네트워크를 함수 호출 한 번으로 만들 수 있습니다.
# - `num_layers`는 컨볼루션 레이어와 디컨볼루션 레이어의 수입니다. 같은 수의 컨볼루션 레이어가 존재하기 때문에, `REDNet-30`이라면 `num_layers=15`를 입력하면 됩니다.
#
# ```python
# conv_layers=[]
# deconv_layers=[]
# residual_layers=[]
# ```
#
# 먼저 세 개의 리스트에 각각 컨볼루션 레이어, 디컨볼루션 레이어, 잔류(`residual`)레이어를 저장합니다.
#
# 각 레이어를 따로 저장할 리스트가 별도로 필요로 합니다.
#
# ```python
#     ...
#     inputs = tf.keras.layers.Input(shape=(None, None, 3))
#     conv_layers.append(tf.keras.layers.Conv2D(3, kernel_size=3, padding='same', activation='relu'))
#
#     for i in range(num_layers-1):
#         conv_layers.append(tf.keras.layers.Conv2D(64, kernel_size=3, padding='same', activation='relu'))
#         deconv_layers.append(tf.keras.layers.Conv2DTranspose(64, kernel_size=3, padding='same', activation='relu'))
#
#     deconv_layers.append(tf.keras.layers.Conv2DTranspose(3, kernel_size=3, padding='same'))
#     ...
# ```
# - 먼저 입력 레이어를 정의합니다. 입력 레이어의 `shape`에서 이미지의 높이와 너비를 `None`으로 지정해서 어떤 크기의 이미지라도 입력으로 받을 수 있습니다.
# - 첫 번째 컨볼루션 레이어와 마지막 디컨볼루션 레이어를 제외한 레이어들은 `for` 문 안에서 정의해서 각 리스트에 저장합니다.
# - 첫번째 컨볼루션 레이어와 마지막 디컨볼루션 레이어는 필터의 수가 다른데 이는 필터의 수로 `RGB` 채널의 수인 `3`을 그대로 받기 위함입니다. 나머지 레이어에서는 64개의 필터를 사용합니다.
#
# ```python
#     # 인코더 시작
#     x = conv_layers[0](inputs)
#
#     for i in range(num_layers-1):
#         x = conv_layers[i+1](x)
#         if i % 2 == 0:
#             residual_layers.append(x)
#
#     # 디코더 시작
#     for i in range(num_layers-1):
#         if i % 2 == 1:
#             x = tf.keras.layers.Add()([x, residual_layers.pop()])
#             x = tf.keras.layers.Activation('relu')(x)
#         x = deconv_layers[i](x)
#
#     x = deconv_layers[-1](x)
# ```
#
# - 여기에서는 `x`라는 변수에 레이어를 계속 적용해서 함수형 `API`를 사용합니다. 마지막에 `x`는 모든 레이어가 적용된 결과가 되기 때문에 모델의 출력이 됩니다.
# - 이렇게 하나의 변수 이름을 재사용하여 레이어를 적용해나가는 방법은 케라스의 함수형 `API`나 `torch`에서 일반적으로 쓰이는 문법입니다.
# - 첫번째 명령인 `x = conv_layers[0](inputs)`의 결과로 `x`는 입력 레이어에 첫 번째 컨볼루션 레이어를 적용한 결과가 됩니다.
#
# ```python
#     for i in range(num_layers-1):
#         x = conv_layers[i+1](x)
#         if i % 2 == 0:
#             residual_layers.append(x)
# ```
# - 그 다음으로는 `for` 문 안에서 `x`에 나머지 컨볼루션 레이어를 계속 적용시키며, 짝수번재 컨볼루션 레이어를 지날 때마다 `x`를 잔류 레이어 리스트에도 저장합니다.
# - 잔류 레이어에 `x`를 저장한 다음 스텝에서 `x`는 다시 컨볼루션 레이어를 통과해서 새로운 값이 되지만 잔류 레이어에 이미 저장된 값은 사라지지 않습니다.
# - 교재 366페이지에 그림설명이 있기 때문에 한번 더 확인하시기를 바랍니다.
#
#
# ```python
#     # 디코더 시작
#     for i in range(num_layers-1):
#         if i % 2 == 1:
#             x = tf.keras.layers.Add()([x, residual_layers.pop()])
#             x = tf.keras.layers.Activation('relu')(x)
#         x = deconv_layers[i](x)
#
#     x = deconv_layers[-1](x)
# ```

# %% [markdown]
# - 두 번째 `for` 문 안에서는 홀수 번째의 디컨볼루션 레이어를 통과할 경우 잔류 레이어 리스트에 저장돼 있던 값을 `residual_layers.pop()`으로 뒤에서부터 하나씩 가져옵니다. 그 다음 합연산과 `ReLU` 활성화함수를 통과한 후 다음 디컨볼루션 레이어에 연결시킵니다.
# - 짝수 번째일 때는 디컨볼루션 레이어만 연결합니다.
#
# ```
# model = tf.keras.Model(inputs=inputs, outputs=x)
# ```
# - `tf.keras`의 함수형 `API`로 `Model`을 만들기 위해서는 입력과 출력만 지정하면 됩니다.
# - 입력인 `inputs`는 함수의 가장 앞에서 정의한 입력 레이어로, 출력인 `outputs`는 지금까지 레이어 연산을 쭉 따라온 변수 이름인 `x`로 넣고, `model`을 반환합니다.

# %% [markdown]
# ### (6) PSNR 계산 공식 및 함수 정의
# - 고해상도 이미지가 잘 복원됐는지 알기 위해서 특별한 측정값을 컴파일에 추가해서 테스트할 수 있습니다.
# - 이 측정값은 `PSNR(Peak Signal-to-Noise Ratio)`, 즉 "신호 대 잡임비"입니다.
# - `PSNR`의 계산 공식은 다음과 같습니다.
#
# $$PSNR = 20\ast log_{10}\frac{Max(pixel)}{\sqrt{MSE}}$$
#
# - 여기서 `Max(pixel)`은 픽셀의 최대값으로, 앞에서 `float32`로 계산했기 때문에 이 값은 `1.0`이 됩니다.
# - `MSE`는 우리가 잘 알고 있는 평균 제곱 오차(`Mean Squared Error`)입니다.
# - 평균 제곱 오차가 로그의 분모에 있기 때문에 이 식은 평균 제곱 오차가 낮을수록 큰 값을 갖게 됩니다.

# %%
def psnr_metric(y_true, y_pred):
  return tf.image.psnr(y_true, y_pred, max_val=1.0)

# %% [markdown]
# - `Metric`은 분류의 정확도(`accuracy`)처럼 `tf.keras`에 등록되어 있을 경우 그대로 사용하면 되지만 `PSNR`은 지원하지 않기 때문에 함수를 만들어줍니다.
# - `y_true`는 정답에 해당하는 값이고, `y_pred`는 네트워크가 학습 결과 예측한 값입니다.
# - 이 둘의 `tf.image.psnr()`을 계산해서 반환하는 것이 `psnr_metric()` 함수의 역할입니다.

# %% [markdown]
# ### (7) REDNet-30 네트워크 초기화 및 컴파일
# - 이제 `REDNet()` 함수로 네트워크를 초기화하고 컴파일합니다.

# %%
model = REDNet(15)
model.compile(optimizer=tf.optimizers.Adam(0.0001), loss='mse', metrics=[psnr_metric])

# %% [markdown]
# - 컴파일된 네트워크 시각화를 작성해봅니다.

# %%
tf.keras.utils.plot_model(model)

# %% [markdown]
# ### (8) REDNet-30 네트워크 학습
# - 이제 네트워크를 학습합니다.

# %%
history = model.fit_generator(train_dataset, 
                              epochs=1000, 
                              steps_per_epoch=len(train_path)//16, 
                              validation_data=valid_dataset, 
                              validation_steps=len(valid_path), 
                              verbose=2)
# Out:
# WARNING:tensorflow:From <ipython-input-15-11785503027a>:6: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/1000
# 12/12 - 4s - loss: 0.2467 - psnr_metric: 7.6192 - val_loss: 0.2287 - val_psnr_metric: 8.1383
# Epoch 2/1000
# 12/12 - 3s - loss: 0.1935 - psnr_metric: 8.8387 - val_loss: 0.0982 - val_psnr_metric: 11.4855
# Epoch 3/1000
# 12/12 - 3s - loss: 0.0926 - psnr_metric: 11.4852 - val_loss: 0.0854 - val_psnr_metric: 11.9134
# Epoch 4/1000
# 12/12 - 3s - loss: 0.0623 - psnr_metric: 12.9788 - val_loss: 0.0702 - val_psnr_metric: 12.8525
# Epoch 5/1000
# 12/12 - 3s - loss: 0.0675 - psnr_metric: 12.7302 - val_loss: 0.0693 - val_psnr_metric: 12.8687
# Epoch 6/1000
# 12/12 - 3s - loss: 0.0626 - psnr_metric: 13.2924 - val_loss: 0.0551 - val_psnr_metric: 13.4513
# Epoch 7/1000
# 12/12 - 3s - loss: 0.0478 - psnr_metric: 14.3724 - val_loss: 0.0529 - val_psnr_metric: 13.9796
# Epoch 8/1000
# 12/12 - 3s - loss: 0.0511 - psnr_metric: 14.0308 - val_loss: 0.0434 - val_psnr_metric: 14.7764
# Epoch 9/1000
# 12/12 - 3s - loss: 0.0381 - psnr_metric: 15.2797 - val_loss: 0.0385 - val_psnr_metric: 15.1949
# Epoch 10/1000
# 12/12 - 3s - loss: 0.0371 - psnr_metric: 15.8048 - val_loss: 0.0361 - val_psnr_metric: 15.5003
# Epoch 11/1000
# 12/12 - 3s - loss: 0.0411 - psnr_metric: 15.3330 - val_loss: 0.0285 - val_psnr_metric: 16.4595
# Epoch 12/1000
# 12/12 - 3s - loss: 0.0349 - psnr_metric: 15.9884 - val_loss: 0.0323 - val_psnr_metric: 16.1947
# Epoch 13/1000
# 12/12 - 3s - loss: 0.0291 - psnr_metric: 16.6989 - val_loss: 0.0269 - val_psnr_metric: 17.0412
# Epoch 14/1000
# 12/12 - 3s - loss: 0.0270 - psnr_metric: 16.8384 - val_loss: 0.0246 - val_psnr_metric: 17.8085
# Epoch 15/1000
# 12/12 - 3s - loss: 0.0232 - psnr_metric: 17.6611 - val_loss: 0.0208 - val_psnr_metric: 18.1434
# Epoch 16/1000
# 12/12 - 3s - loss: 0.0218 - psnr_metric: 18.2046 - val_loss: 0.0165 - val_psnr_metric: 18.9731
# Epoch 17/1000
# 12/12 - 3s - loss: 0.0193 - psnr_metric: 18.9413 - val_loss: 0.0151 - val_psnr_metric: 19.6297
# Epoch 18/1000
# 12/12 - 3s - loss: 0.0157 - psnr_metric: 19.4490 - val_loss: 0.0164 - val_psnr_metric: 19.2980
# Epoch 19/1000
# 12/12 - 3s - loss: 0.0155 - psnr_metric: 19.5989 - val_loss: 0.0200 - val_psnr_metric: 18.8926
# Epoch 20/1000
# 12/12 - 3s - loss: 0.0150 - psnr_metric: 19.9430 - val_loss: 0.0159 - val_psnr_metric: 19.9075
# Epoch 21/1000
# 12/12 - 3s - loss: 0.0143 - psnr_metric: 20.3413 - val_loss: 0.0134 - val_psnr_metric: 20.8026
# Epoch 22/1000
# 12/12 - 3s - loss: 0.0133 - psnr_metric: 20.5410 - val_loss: 0.0121 - val_psnr_metric: 20.6387
# Epoch 23/1000
# 12/12 - 3s - loss: 0.0119 - psnr_metric: 20.8812 - val_loss: 0.0109 - val_psnr_metric: 21.5027
# Epoch 24/1000
# 12/12 - 3s - loss: 0.0115 - psnr_metric: 21.2345 - val_loss: 0.0093 - val_psnr_metric: 21.8251
# Epoch 25/1000
# 12/12 - 3s - loss: 0.0113 - psnr_metric: 21.2758 - val_loss: 0.0107 - val_psnr_metric: 21.6211
# Epoch 26/1000
# 12/12 - 3s - loss: 0.0094 - psnr_metric: 21.9835 - val_loss: 0.0126 - val_psnr_metric: 20.6691
# Epoch 27/1000
# 12/12 - 3s - loss: 0.0102 - psnr_metric: 21.8491 - val_loss: 0.0095 - val_psnr_metric: 21.8564
# Epoch 28/1000
# 12/12 - 3s - loss: 0.0096 - psnr_metric: 22.1255 - val_loss: 0.0101 - val_psnr_metric: 21.4665
# Epoch 29/1000
# 12/12 - 3s - loss: 0.0097 - psnr_metric: 21.7544 - val_loss: 0.0106 - val_psnr_metric: 21.9990
# Epoch 30/1000
# 12/12 - 3s - loss: 0.0096 - psnr_metric: 21.9238 - val_loss: 0.0084 - val_psnr_metric: 22.6039
# Epoch 31/1000
# 12/12 - 3s - loss: 0.0089 - psnr_metric: 22.1938 - val_loss: 0.0085 - val_psnr_metric: 22.3306
# Epoch 32/1000
# 12/12 - 3s - loss: 0.0080 - psnr_metric: 22.7946 - val_loss: 0.0093 - val_psnr_metric: 21.9881
# Epoch 33/1000
# 12/12 - 3s - loss: 0.0082 - psnr_metric: 22.8976 - val_loss: 0.0087 - val_psnr_metric: 22.3070
# Epoch 34/1000
# 12/12 - 3s - loss: 0.0077 - psnr_metric: 22.9827 - val_loss: 0.0080 - val_psnr_metric: 22.5272
# Epoch 35/1000
# 12/12 - 3s - loss: 0.0067 - psnr_metric: 23.3223 - val_loss: 0.0084 - val_psnr_metric: 22.6127
# Epoch 36/1000
# 12/12 - 3s - loss: 0.0069 - psnr_metric: 23.6194 - val_loss: 0.0071 - val_psnr_metric: 23.2287
# Epoch 37/1000
# 12/12 - 3s - loss: 0.0075 - psnr_metric: 23.1671 - val_loss: 0.0067 - val_psnr_metric: 23.5863
# Epoch 38/1000
# 12/12 - 3s - loss: 0.0067 - psnr_metric: 23.5441 - val_loss: 0.0078 - val_psnr_metric: 23.4869
# Epoch 39/1000
# 12/12 - 3s - loss: 0.0062 - psnr_metric: 23.5614 - val_loss: 0.0072 - val_psnr_metric: 23.0786
# Epoch 40/1000
# 12/12 - 3s - loss: 0.0054 - psnr_metric: 24.5457 - val_loss: 0.0050 - val_psnr_metric: 24.5279
# Epoch 41/1000
# 12/12 - 3s - loss: 0.0064 - psnr_metric: 23.9420 - val_loss: 0.0046 - val_psnr_metric: 25.2076
# Epoch 42/1000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 24.7648 - val_loss: 0.0047 - val_psnr_metric: 25.0270
# Epoch 43/1000
# 12/12 - 3s - loss: 0.0055 - psnr_metric: 24.2511 - val_loss: 0.0056 - val_psnr_metric: 25.0507
# Epoch 44/1000
# 12/12 - 4s - loss: 0.0048 - psnr_metric: 25.1861 - val_loss: 0.0043 - val_psnr_metric: 25.6208
# Epoch 45/1000
# 12/12 - 4s - loss: 0.0049 - psnr_metric: 25.1704 - val_loss: 0.0044 - val_psnr_metric: 25.2845
# Epoch 46/1000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 25.6367 - val_loss: 0.0037 - val_psnr_metric: 26.1477
# Epoch 47/1000
# 12/12 - 3s - loss: 0.0037 - psnr_metric: 26.2473 - val_loss: 0.0046 - val_psnr_metric: 25.3847
# Epoch 48/1000
# 12/12 - 3s - loss: 0.0040 - psnr_metric: 26.2042 - val_loss: 0.0039 - val_psnr_metric: 26.3214
# Epoch 49/1000
# 12/12 - 3s - loss: 0.0040 - psnr_metric: 26.4800 - val_loss: 0.0034 - val_psnr_metric: 26.5551
# Epoch 50/1000
# 12/12 - 3s - loss: 0.0036 - psnr_metric: 26.6685 - val_loss: 0.0036 - val_psnr_metric: 25.9435
# Epoch 51/1000
# 12/12 - 3s - loss: 0.0035 - psnr_metric: 26.5830 - val_loss: 0.0034 - val_psnr_metric: 27.1368
# Epoch 52/1000
# 12/12 - 3s - loss: 0.0036 - psnr_metric: 25.9197 - val_loss: 0.0034 - val_psnr_metric: 26.5601
# Epoch 53/1000
# 12/12 - 3s - loss: 0.0033 - psnr_metric: 26.7479 - val_loss: 0.0033 - val_psnr_metric: 26.7451
# Epoch 54/1000
# 12/12 - 3s - loss: 0.0039 - psnr_metric: 26.1829 - val_loss: 0.0034 - val_psnr_metric: 26.8970
# Epoch 55/1000
# 12/12 - 3s - loss: 0.0035 - psnr_metric: 26.4828 - val_loss: 0.0030 - val_psnr_metric: 26.9088
# Epoch 56/1000
# 12/12 - 3s - loss: 0.0034 - psnr_metric: 26.7833 - val_loss: 0.0035 - val_psnr_metric: 26.6046
# Epoch 57/1000
# 12/12 - 3s - loss: 0.0032 - psnr_metric: 27.3380 - val_loss: 0.0033 - val_psnr_metric: 26.5539
# Epoch 58/1000
# 12/12 - 3s - loss: 0.0028 - psnr_metric: 27.7654 - val_loss: 0.0031 - val_psnr_metric: 27.2311
# Epoch 59/1000
# 12/12 - 3s - loss: 0.0032 - psnr_metric: 27.2006 - val_loss: 0.0028 - val_psnr_metric: 27.5178
# Epoch 60/1000
# 12/12 - 3s - loss: 0.0034 - psnr_metric: 26.9622 - val_loss: 0.0032 - val_psnr_metric: 26.8582
# Epoch 61/1000
# 12/12 - 3s - loss: 0.0032 - psnr_metric: 26.9408 - val_loss: 0.0031 - val_psnr_metric: 27.4529
# Epoch 62/1000
# 12/12 - 3s - loss: 0.0030 - psnr_metric: 27.6295 - val_loss: 0.0025 - val_psnr_metric: 28.1934
# Epoch 63/1000
# 12/12 - 3s - loss: 0.0030 - psnr_metric: 27.4704 - val_loss: 0.0031 - val_psnr_metric: 26.6799
# Epoch 64/1000
# 12/12 - 3s - loss: 0.0028 - psnr_metric: 27.3298 - val_loss: 0.0031 - val_psnr_metric: 28.0227
# Epoch 65/1000
# 12/12 - 3s - loss: 0.0031 - psnr_metric: 27.2716 - val_loss: 0.0031 - val_psnr_metric: 26.8140
# Epoch 66/1000
# 12/12 - 3s - loss: 0.0030 - psnr_metric: 27.8878 - val_loss: 0.0027 - val_psnr_metric: 27.7056
# Epoch 67/1000
# 12/12 - 3s - loss: 0.0028 - psnr_metric: 28.1180 - val_loss: 0.0025 - val_psnr_metric: 28.9055
# Epoch 68/1000
# 12/12 - 3s - loss: 0.0026 - psnr_metric: 27.6508 - val_loss: 0.0028 - val_psnr_metric: 27.6089
# Epoch 69/1000
# 12/12 - 3s - loss: 0.0028 - psnr_metric: 27.6906 - val_loss: 0.0025 - val_psnr_metric: 29.1097
# Epoch 70/1000
# 12/12 - 3s - loss: 0.0026 - psnr_metric: 28.0252 - val_loss: 0.0029 - val_psnr_metric: 27.6308
# Epoch 71/1000
# 12/12 - 3s - loss: 0.0030 - psnr_metric: 27.7405 - val_loss: 0.0030 - val_psnr_metric: 27.5894
# Epoch 72/1000
# 12/12 - 3s - loss: 0.0025 - psnr_metric: 27.8796 - val_loss: 0.0026 - val_psnr_metric: 28.0978
# Epoch 73/1000
# 12/12 - 3s - loss: 0.0028 - psnr_metric: 28.1430 - val_loss: 0.0025 - val_psnr_metric: 28.5845
# Epoch 74/1000
# 12/12 - 3s - loss: 0.0025 - psnr_metric: 28.4024 - val_loss: 0.0027 - val_psnr_metric: 28.4169
# Epoch 75/1000
# 12/12 - 3s - loss: 0.0028 - psnr_metric: 28.4058 - val_loss: 0.0026 - val_psnr_metric: 28.2184
# Epoch 76/1000
# 12/12 - 3s - loss: 0.0027 - psnr_metric: 28.3174 - val_loss: 0.0025 - val_psnr_metric: 27.9038
# Epoch 77/1000
# 12/12 - 3s - loss: 0.0027 - psnr_metric: 27.8603 - val_loss: 0.0029 - val_psnr_metric: 27.8378
# Epoch 78/1000
# 12/12 - 3s - loss: 0.0032 - psnr_metric: 27.0440 - val_loss: 0.0028 - val_psnr_metric: 28.0239
# Epoch 79/1000
# 12/12 - 3s - loss: 0.0025 - psnr_metric: 27.9729 - val_loss: 0.0025 - val_psnr_metric: 28.5124
# Epoch 80/1000
# 12/12 - 3s - loss: 0.0025 - psnr_metric: 28.5281 - val_loss: 0.0023 - val_psnr_metric: 28.6096
# Epoch 81/1000
# 12/12 - 3s - loss: 0.0026 - psnr_metric: 28.2374 - val_loss: 0.0024 - val_psnr_metric: 28.9566
# Epoch 82/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.1543 - val_loss: 0.0024 - val_psnr_metric: 28.4534
# Epoch 83/1000
# 12/12 - 3s - loss: 0.0025 - psnr_metric: 28.4547 - val_loss: 0.0024 - val_psnr_metric: 28.2817
# Epoch 84/1000
# 12/12 - 3s - loss: 0.0025 - psnr_metric: 28.5343 - val_loss: 0.0028 - val_psnr_metric: 27.2612
# Epoch 85/1000
# 12/12 - 3s - loss: 0.0027 - psnr_metric: 28.0199 - val_loss: 0.0021 - val_psnr_metric: 28.9508
# Epoch 86/1000
# 12/12 - 3s - loss: 0.0025 - psnr_metric: 28.5378 - val_loss: 0.0026 - val_psnr_metric: 28.8252
# Epoch 87/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 28.9126 - val_loss: 0.0026 - val_psnr_metric: 28.9179
# Epoch 88/1000
# 12/12 - 3s - loss: 0.0024 - psnr_metric: 29.0154 - val_loss: 0.0025 - val_psnr_metric: 28.6394
# Epoch 89/1000
# 12/12 - 3s - loss: 0.0027 - psnr_metric: 28.7949 - val_loss: 0.0025 - val_psnr_metric: 28.7105
# Epoch 90/1000
# 12/12 - 3s - loss: 0.0024 - psnr_metric: 29.2994 - val_loss: 0.0022 - val_psnr_metric: 28.6984
# Epoch 91/1000
# 12/12 - 3s - loss: 0.0027 - psnr_metric: 28.2538 - val_loss: 0.0022 - val_psnr_metric: 29.0046
# Epoch 92/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.1646 - val_loss: 0.0018 - val_psnr_metric: 30.1338
# Epoch 93/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.0920 - val_loss: 0.0026 - val_psnr_metric: 29.0848
# Epoch 94/1000
# 12/12 - 3s - loss: 0.0022 - psnr_metric: 28.9894 - val_loss: 0.0021 - val_psnr_metric: 30.4347
# Epoch 95/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.0625 - val_loss: 0.0026 - val_psnr_metric: 28.3461
# Epoch 96/1000
# 12/12 - 3s - loss: 0.0024 - psnr_metric: 28.7983 - val_loss: 0.0026 - val_psnr_metric: 28.0988
# Epoch 97/1000
# 12/12 - 3s - loss: 0.0025 - psnr_metric: 28.1074 - val_loss: 0.0025 - val_psnr_metric: 28.3104
# Epoch 98/1000
# 12/12 - 3s - loss: 0.0027 - psnr_metric: 27.9480 - val_loss: 0.0022 - val_psnr_metric: 29.2004
# Epoch 99/1000
# 12/12 - 3s - loss: 0.0026 - psnr_metric: 28.3426 - val_loss: 0.0019 - val_psnr_metric: 29.6136
# Epoch 100/1000
# 12/12 - 3s - loss: 0.0026 - psnr_metric: 27.9386 - val_loss: 0.0031 - val_psnr_metric: 27.2998
# Epoch 101/1000
# 12/12 - 3s - loss: 0.0026 - psnr_metric: 28.6210 - val_loss: 0.0022 - val_psnr_metric: 28.3730
# Epoch 102/1000
# 12/12 - 3s - loss: 0.0024 - psnr_metric: 28.7443 - val_loss: 0.0022 - val_psnr_metric: 28.5996
# Epoch 103/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 29.8136 - val_loss: 0.0022 - val_psnr_metric: 29.6244
# Epoch 104/1000
# 12/12 - 3s - loss: 0.0024 - psnr_metric: 29.1939 - val_loss: 0.0024 - val_psnr_metric: 29.4850
# Epoch 105/1000
# 12/12 - 3s - loss: 0.0022 - psnr_metric: 29.6011 - val_loss: 0.0022 - val_psnr_metric: 29.1263
# Epoch 106/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 29.7784 - val_loss: 0.0021 - val_psnr_metric: 29.3131
# Epoch 107/1000
# 12/12 - 3s - loss: 0.0022 - psnr_metric: 29.6367 - val_loss: 0.0021 - val_psnr_metric: 30.0412
# Epoch 108/1000
# 12/12 - 3s - loss: 0.0024 - psnr_metric: 28.6443 - val_loss: 0.0023 - val_psnr_metric: 28.7811
# Epoch 109/1000
# 12/12 - 3s - loss: 0.0025 - psnr_metric: 28.7422 - val_loss: 0.0026 - val_psnr_metric: 29.4669
# Epoch 110/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 29.7944 - val_loss: 0.0019 - val_psnr_metric: 30.1458
# Epoch 111/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 29.9032 - val_loss: 0.0021 - val_psnr_metric: 29.5802
# Epoch 112/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.5011 - val_loss: 0.0020 - val_psnr_metric: 29.8833
# Epoch 113/1000
# 12/12 - 3s - loss: 0.0024 - psnr_metric: 29.0065 - val_loss: 0.0024 - val_psnr_metric: 28.7527
# Epoch 114/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.5383 - val_loss: 0.0020 - val_psnr_metric: 30.1093
# Epoch 115/1000
# 12/12 - 3s - loss: 0.0024 - psnr_metric: 28.9618 - val_loss: 0.0022 - val_psnr_metric: 29.6261
# Epoch 116/1000
# 12/12 - 3s - loss: 0.0025 - psnr_metric: 28.9016 - val_loss: 0.0024 - val_psnr_metric: 29.1693
# Epoch 117/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.2294 - val_loss: 0.0028 - val_psnr_metric: 27.9124
# Epoch 118/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 29.3902 - val_loss: 0.0026 - val_psnr_metric: 28.9158
# Epoch 119/1000
# 12/12 - 3s - loss: 0.0025 - psnr_metric: 29.0612 - val_loss: 0.0024 - val_psnr_metric: 29.2430
# Epoch 120/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 30.1493 - val_loss: 0.0018 - val_psnr_metric: 30.7474
# Epoch 121/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.3721 - val_loss: 0.0023 - val_psnr_metric: 29.3473
# Epoch 122/1000
# 12/12 - 3s - loss: 0.0022 - psnr_metric: 29.7182 - val_loss: 0.0025 - val_psnr_metric: 28.6149
# Epoch 123/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.4830 - val_loss: 0.0026 - val_psnr_metric: 28.1911
# Epoch 124/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.1159 - val_loss: 0.0023 - val_psnr_metric: 28.8228
# Epoch 125/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.2185 - val_loss: 0.0020 - val_psnr_metric: 29.9381
# Epoch 126/1000
# 12/12 - 3s - loss: 0.0025 - psnr_metric: 28.8218 - val_loss: 0.0027 - val_psnr_metric: 27.7117
# Epoch 127/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 29.8402 - val_loss: 0.0019 - val_psnr_metric: 30.0513
# Epoch 128/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 29.3005 - val_loss: 0.0022 - val_psnr_metric: 29.8363
# Epoch 129/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.3425 - val_loss: 0.0020 - val_psnr_metric: 29.9317
# Epoch 130/1000
# 12/12 - 3s - loss: 0.0022 - psnr_metric: 29.9226 - val_loss: 0.0021 - val_psnr_metric: 29.4343
# Epoch 131/1000
# 12/12 - 4s - loss: 0.0021 - psnr_metric: 29.6718 - val_loss: 0.0020 - val_psnr_metric: 29.4243
# Epoch 132/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 29.6458 - val_loss: 0.0021 - val_psnr_metric: 29.8641
# Epoch 133/1000
# 12/12 - 3s - loss: 0.0024 - psnr_metric: 29.2326 - val_loss: 0.0020 - val_psnr_metric: 29.0559
# Epoch 134/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.3047 - val_loss: 0.0024 - val_psnr_metric: 29.5266
# Epoch 135/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.5036 - val_loss: 0.0019 - val_psnr_metric: 30.6371
# Epoch 136/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 30.4019 - val_loss: 0.0021 - val_psnr_metric: 29.6531
# Epoch 137/1000
# 12/12 - 3s - loss: 0.0022 - psnr_metric: 29.5481 - val_loss: 0.0020 - val_psnr_metric: 30.1638
# Epoch 138/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.1705 - val_loss: 0.0020 - val_psnr_metric: 30.1703
# Epoch 139/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.6618 - val_loss: 0.0018 - val_psnr_metric: 30.5783
# Epoch 140/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.4189 - val_loss: 0.0018 - val_psnr_metric: 30.0695
# Epoch 141/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 29.7848 - val_loss: 0.0020 - val_psnr_metric: 29.9695
# Epoch 142/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 29.5197 - val_loss: 0.0018 - val_psnr_metric: 30.1035
# Epoch 143/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 29.2629 - val_loss: 0.0019 - val_psnr_metric: 29.7674
# Epoch 144/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.4028 - val_loss: 0.0017 - val_psnr_metric: 30.6013
# Epoch 145/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.2402 - val_loss: 0.0024 - val_psnr_metric: 30.0715
# Epoch 146/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.2042 - val_loss: 0.0021 - val_psnr_metric: 31.2897
# Epoch 147/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 30.2336 - val_loss: 0.0025 - val_psnr_metric: 29.7807
# Epoch 148/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.4946 - val_loss: 0.0016 - val_psnr_metric: 31.2286
# Epoch 149/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 30.2094 - val_loss: 0.0021 - val_psnr_metric: 29.8085
# Epoch 150/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.2232 - val_loss: 0.0019 - val_psnr_metric: 30.6955
# Epoch 151/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 30.0610 - val_loss: 0.0019 - val_psnr_metric: 29.9086
# Epoch 152/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 29.7656 - val_loss: 0.0019 - val_psnr_metric: 30.4080
# Epoch 153/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 30.3857 - val_loss: 0.0017 - val_psnr_metric: 30.7634
# Epoch 154/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 29.9974 - val_loss: 0.0020 - val_psnr_metric: 29.6959
# Epoch 155/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 30.0563 - val_loss: 0.0020 - val_psnr_metric: 30.0096
# Epoch 156/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.6912 - val_loss: 0.0020 - val_psnr_metric: 29.6651
# Epoch 157/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 29.8087 - val_loss: 0.0019 - val_psnr_metric: 29.7359
# Epoch 158/1000
# 12/12 - 3s - loss: 0.0022 - psnr_metric: 29.6075 - val_loss: 0.0020 - val_psnr_metric: 29.7564
# Epoch 159/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.3228 - val_loss: 0.0020 - val_psnr_metric: 30.5589
# Epoch 160/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.7235 - val_loss: 0.0020 - val_psnr_metric: 29.9864
# Epoch 161/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 30.3408 - val_loss: 0.0018 - val_psnr_metric: 30.2077
# Epoch 162/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 29.7399 - val_loss: 0.0023 - val_psnr_metric: 29.9423
# Epoch 163/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.5815 - val_loss: 0.0019 - val_psnr_metric: 30.8773
# Epoch 164/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.7876 - val_loss: 0.0024 - val_psnr_metric: 30.1389
# Epoch 165/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.5309 - val_loss: 0.0020 - val_psnr_metric: 30.9827
# Epoch 166/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.5454 - val_loss: 0.0022 - val_psnr_metric: 29.6502
# Epoch 167/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.4079 - val_loss: 0.0022 - val_psnr_metric: 30.3772
# Epoch 168/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 30.1274 - val_loss: 0.0019 - val_psnr_metric: 30.5826
# Epoch 169/1000
# 12/12 - 3s - loss: 0.0022 - psnr_metric: 29.9442 - val_loss: 0.0018 - val_psnr_metric: 30.9725
# Epoch 170/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.8991 - val_loss: 0.0020 - val_psnr_metric: 30.7398
# Epoch 171/1000
# 12/12 - 3s - loss: 0.0022 - psnr_metric: 30.1968 - val_loss: 0.0016 - val_psnr_metric: 30.8594
# Epoch 172/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.1378 - val_loss: 0.0020 - val_psnr_metric: 30.2594
# Epoch 173/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 29.7546 - val_loss: 0.0018 - val_psnr_metric: 30.5936
# Epoch 174/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 29.8727 - val_loss: 0.0019 - val_psnr_metric: 30.7303
# Epoch 175/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 29.5497 - val_loss: 0.0019 - val_psnr_metric: 29.6750
# Epoch 176/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 29.6962 - val_loss: 0.0020 - val_psnr_metric: 29.2898
# Epoch 177/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.0593 - val_loss: 0.0020 - val_psnr_metric: 29.5411
# Epoch 178/1000
# 12/12 - 3s - loss: 0.0022 - psnr_metric: 29.7428 - val_loss: 0.0022 - val_psnr_metric: 28.9199
# Epoch 179/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.4721 - val_loss: 0.0024 - val_psnr_metric: 29.4676
# Epoch 180/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 30.7285 - val_loss: 0.0017 - val_psnr_metric: 30.8571
# Epoch 181/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.9200 - val_loss: 0.0020 - val_psnr_metric: 30.7111
# Epoch 182/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 29.8513 - val_loss: 0.0022 - val_psnr_metric: 30.2654
# Epoch 183/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.4785 - val_loss: 0.0021 - val_psnr_metric: 30.1261
# Epoch 184/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.0719 - val_loss: 0.0021 - val_psnr_metric: 29.7800
# Epoch 185/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 29.3597 - val_loss: 0.0021 - val_psnr_metric: 30.3643
# Epoch 186/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 30.1730 - val_loss: 0.0017 - val_psnr_metric: 31.0127
# Epoch 187/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 31.1420 - val_loss: 0.0017 - val_psnr_metric: 30.6964
# Epoch 188/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.6444 - val_loss: 0.0016 - val_psnr_metric: 31.4945
# Epoch 189/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.6832 - val_loss: 0.0018 - val_psnr_metric: 30.0360
# Epoch 190/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.8798 - val_loss: 0.0022 - val_psnr_metric: 30.6346
# Epoch 191/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.5156 - val_loss: 0.0021 - val_psnr_metric: 29.4910
# Epoch 192/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.2557 - val_loss: 0.0021 - val_psnr_metric: 30.2553
# Epoch 193/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.7423 - val_loss: 0.0016 - val_psnr_metric: 31.3210
# Epoch 194/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 30.2256 - val_loss: 0.0019 - val_psnr_metric: 31.3794
# Epoch 195/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.8585 - val_loss: 0.0019 - val_psnr_metric: 30.8058
# Epoch 196/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 30.1614 - val_loss: 0.0019 - val_psnr_metric: 30.1033
# Epoch 197/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.4474 - val_loss: 0.0018 - val_psnr_metric: 30.2290
# Epoch 198/1000
# 12/12 - 3s - loss: 0.0023 - psnr_metric: 29.7953 - val_loss: 0.0018 - val_psnr_metric: 30.6261
# Epoch 199/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.7383 - val_loss: 0.0019 - val_psnr_metric: 30.0621
# Epoch 200/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.0894 - val_loss: 0.0019 - val_psnr_metric: 30.8276
# Epoch 201/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.4313 - val_loss: 0.0018 - val_psnr_metric: 30.3992
# Epoch 202/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.2609 - val_loss: 0.0018 - val_psnr_metric: 31.2053
# Epoch 203/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 30.4816 - val_loss: 0.0021 - val_psnr_metric: 30.0486
# Epoch 204/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.4633 - val_loss: 0.0019 - val_psnr_metric: 32.3432
# Epoch 205/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.4122 - val_loss: 0.0020 - val_psnr_metric: 30.6005
# Epoch 206/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.5511 - val_loss: 0.0018 - val_psnr_metric: 30.8251
# Epoch 207/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 30.1418 - val_loss: 0.0021 - val_psnr_metric: 30.4874
# Epoch 208/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.7665 - val_loss: 0.0016 - val_psnr_metric: 30.8648
# Epoch 209/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.6560 - val_loss: 0.0017 - val_psnr_metric: 30.6792
# Epoch 210/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 30.0531 - val_loss: 0.0018 - val_psnr_metric: 30.7702
# Epoch 211/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 30.0244 - val_loss: 0.0018 - val_psnr_metric: 29.2239
# Epoch 212/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 29.5256 - val_loss: 0.0017 - val_psnr_metric: 30.7566
# Epoch 213/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 30.3054 - val_loss: 0.0021 - val_psnr_metric: 30.4613
# Epoch 214/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.3548 - val_loss: 0.0017 - val_psnr_metric: 31.2739
# Epoch 215/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 30.8152 - val_loss: 0.0015 - val_psnr_metric: 31.8091
# Epoch 216/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.7321 - val_loss: 0.0015 - val_psnr_metric: 31.6492
# Epoch 217/1000
# 12/12 - 4s - loss: 0.0017 - psnr_metric: 31.4085 - val_loss: 0.0018 - val_psnr_metric: 31.1153
# Epoch 218/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 30.3135 - val_loss: 0.0018 - val_psnr_metric: 30.7658
# Epoch 219/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 31.3657 - val_loss: 0.0020 - val_psnr_metric: 30.3716
# Epoch 220/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 30.9187 - val_loss: 0.0020 - val_psnr_metric: 29.8207
# Epoch 221/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 30.7228 - val_loss: 0.0019 - val_psnr_metric: 29.9909
# Epoch 222/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.3968 - val_loss: 0.0019 - val_psnr_metric: 30.0300
# Epoch 223/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.2454 - val_loss: 0.0019 - val_psnr_metric: 30.3642
# Epoch 224/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.6625 - val_loss: 0.0018 - val_psnr_metric: 30.8439
# Epoch 225/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.0622 - val_loss: 0.0017 - val_psnr_metric: 30.5690
# Epoch 226/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.3181 - val_loss: 0.0016 - val_psnr_metric: 31.4895
# Epoch 227/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.9127 - val_loss: 0.0020 - val_psnr_metric: 30.2665
# Epoch 228/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 31.0312 - val_loss: 0.0017 - val_psnr_metric: 30.6308
# Epoch 229/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.9153 - val_loss: 0.0017 - val_psnr_metric: 31.0814
# Epoch 230/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.6928 - val_loss: 0.0017 - val_psnr_metric: 31.1675
# Epoch 231/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.2060 - val_loss: 0.0019 - val_psnr_metric: 30.6014
# Epoch 232/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.3310 - val_loss: 0.0021 - val_psnr_metric: 30.7917
# Epoch 233/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.6471 - val_loss: 0.0021 - val_psnr_metric: 30.0702
# Epoch 234/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.6735 - val_loss: 0.0019 - val_psnr_metric: 30.4910
# Epoch 235/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 30.5493 - val_loss: 0.0020 - val_psnr_metric: 29.2587
# Epoch 236/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 29.2696 - val_loss: 0.0020 - val_psnr_metric: 29.2479
# Epoch 237/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 30.0170 - val_loss: 0.0021 - val_psnr_metric: 30.0700
# Epoch 238/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.3730 - val_loss: 0.0020 - val_psnr_metric: 30.1545
# Epoch 239/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.6710 - val_loss: 0.0019 - val_psnr_metric: 30.4670
# Epoch 240/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 30.9603 - val_loss: 0.0020 - val_psnr_metric: 30.3248
# Epoch 241/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 30.9338 - val_loss: 0.0020 - val_psnr_metric: 29.9930
# Epoch 242/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.5630 - val_loss: 0.0019 - val_psnr_metric: 30.5828
# Epoch 243/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.6817 - val_loss: 0.0015 - val_psnr_metric: 30.7711
# Epoch 244/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.9396 - val_loss: 0.0016 - val_psnr_metric: 31.4172
# Epoch 245/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.4188 - val_loss: 0.0015 - val_psnr_metric: 31.5838
# Epoch 246/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 30.6849 - val_loss: 0.0020 - val_psnr_metric: 30.5970
# Epoch 247/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 30.0897 - val_loss: 0.0017 - val_psnr_metric: 30.5170
# Epoch 248/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.6472 - val_loss: 0.0016 - val_psnr_metric: 30.8680
# Epoch 249/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.5303 - val_loss: 0.0018 - val_psnr_metric: 30.8734
# Epoch 250/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 30.1932 - val_loss: 0.0019 - val_psnr_metric: 30.1145
# Epoch 251/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.4674 - val_loss: 0.0020 - val_psnr_metric: 30.5424
# Epoch 252/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.4420 - val_loss: 0.0017 - val_psnr_metric: 30.4733
# Epoch 253/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.0589 - val_loss: 0.0017 - val_psnr_metric: 31.9874
# Epoch 254/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.4089 - val_loss: 0.0018 - val_psnr_metric: 30.8773
# Epoch 255/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.0575 - val_loss: 0.0016 - val_psnr_metric: 31.4990
# Epoch 256/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.2229 - val_loss: 0.0018 - val_psnr_metric: 30.4142
# Epoch 257/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.5916 - val_loss: 0.0020 - val_psnr_metric: 31.0391
# Epoch 258/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.6626 - val_loss: 0.0019 - val_psnr_metric: 31.0950
# Epoch 259/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 31.6905 - val_loss: 0.0018 - val_psnr_metric: 31.0587
# Epoch 260/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.1714 - val_loss: 0.0019 - val_psnr_metric: 30.4752
# Epoch 261/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 30.7154 - val_loss: 0.0020 - val_psnr_metric: 30.1022
# Epoch 262/1000
# 12/12 - 3s - loss: 0.0021 - psnr_metric: 29.9834 - val_loss: 0.0019 - val_psnr_metric: 30.2028
# Epoch 263/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 30.8665 - val_loss: 0.0017 - val_psnr_metric: 31.2310
# Epoch 264/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.6814 - val_loss: 0.0019 - val_psnr_metric: 31.1264
# Epoch 265/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.0506 - val_loss: 0.0017 - val_psnr_metric: 30.8343
# Epoch 266/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.5349 - val_loss: 0.0016 - val_psnr_metric: 30.8821
# Epoch 267/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.2273 - val_loss: 0.0020 - val_psnr_metric: 30.3669
# Epoch 268/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 30.4935 - val_loss: 0.0019 - val_psnr_metric: 30.8702
# Epoch 269/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.1188 - val_loss: 0.0017 - val_psnr_metric: 30.9718
# Epoch 270/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 30.4402 - val_loss: 0.0017 - val_psnr_metric: 30.8735
# Epoch 271/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.1837 - val_loss: 0.0017 - val_psnr_metric: 30.9672
# Epoch 272/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.0065 - val_loss: 0.0020 - val_psnr_metric: 29.7443
# Epoch 273/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.5275 - val_loss: 0.0014 - val_psnr_metric: 31.8419
# Epoch 274/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 31.1059 - val_loss: 0.0017 - val_psnr_metric: 31.9365
# Epoch 275/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.7152 - val_loss: 0.0019 - val_psnr_metric: 30.5509
# Epoch 276/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.4609 - val_loss: 0.0016 - val_psnr_metric: 30.5695
# Epoch 277/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.0775 - val_loss: 0.0018 - val_psnr_metric: 31.5748
# Epoch 278/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 31.0173 - val_loss: 0.0019 - val_psnr_metric: 30.6322
# Epoch 279/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.4464 - val_loss: 0.0016 - val_psnr_metric: 31.3777
# Epoch 280/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.7980 - val_loss: 0.0018 - val_psnr_metric: 31.3501
# Epoch 281/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.0615 - val_loss: 0.0017 - val_psnr_metric: 30.9959
# Epoch 282/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.0749 - val_loss: 0.0017 - val_psnr_metric: 30.7265
# Epoch 283/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.8976 - val_loss: 0.0020 - val_psnr_metric: 30.0510
# Epoch 284/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.0577 - val_loss: 0.0018 - val_psnr_metric: 30.8263
# Epoch 285/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.9785 - val_loss: 0.0018 - val_psnr_metric: 31.1243
# Epoch 286/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.4794 - val_loss: 0.0022 - val_psnr_metric: 30.1748
# Epoch 287/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.3190 - val_loss: 0.0019 - val_psnr_metric: 30.8083
# Epoch 288/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.8337 - val_loss: 0.0017 - val_psnr_metric: 31.4336
# Epoch 289/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 31.8136 - val_loss: 0.0017 - val_psnr_metric: 30.5084
# Epoch 290/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.7006 - val_loss: 0.0017 - val_psnr_metric: 31.0155
# Epoch 291/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.6425 - val_loss: 0.0017 - val_psnr_metric: 30.6564
# Epoch 292/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.8049 - val_loss: 0.0017 - val_psnr_metric: 31.0405
# Epoch 293/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.4983 - val_loss: 0.0019 - val_psnr_metric: 31.2952
# Epoch 294/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.1701 - val_loss: 0.0019 - val_psnr_metric: 30.3250
# Epoch 295/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.8566 - val_loss: 0.0017 - val_psnr_metric: 31.8695
# Epoch 296/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.3389 - val_loss: 0.0018 - val_psnr_metric: 30.5059
# Epoch 297/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.5883 - val_loss: 0.0013 - val_psnr_metric: 32.8959
# Epoch 298/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 30.0127 - val_loss: 0.0018 - val_psnr_metric: 30.7373
# Epoch 299/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.6455 - val_loss: 0.0019 - val_psnr_metric: 29.7770
# Epoch 300/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.3081 - val_loss: 0.0021 - val_psnr_metric: 28.6159
# Epoch 301/1000
# 12/12 - 3s - loss: 0.0029 - psnr_metric: 27.2979 - val_loss: 0.0051 - val_psnr_metric: 24.3410
# Epoch 302/1000
# 12/12 - 3s - loss: 0.0029 - psnr_metric: 27.2218 - val_loss: 0.0033 - val_psnr_metric: 26.8265
# Epoch 303/1000
# 12/12 - 4s - loss: 0.0024 - psnr_metric: 28.1134 - val_loss: 0.0027 - val_psnr_metric: 28.0862
# Epoch 304/1000
# 12/12 - 3s - loss: 0.0022 - psnr_metric: 29.2966 - val_loss: 0.0017 - val_psnr_metric: 31.2009
# Epoch 305/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 30.2779 - val_loss: 0.0017 - val_psnr_metric: 30.4775
# Epoch 306/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.1537 - val_loss: 0.0017 - val_psnr_metric: 30.7796
# Epoch 307/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.7306 - val_loss: 0.0019 - val_psnr_metric: 31.2795
# Epoch 308/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.8298 - val_loss: 0.0016 - val_psnr_metric: 31.4634
# Epoch 309/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 30.8239 - val_loss: 0.0017 - val_psnr_metric: 31.0850
# Epoch 310/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.3731 - val_loss: 0.0017 - val_psnr_metric: 32.1935
# Epoch 311/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.5012 - val_loss: 0.0018 - val_psnr_metric: 30.8848
# Epoch 312/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.9899 - val_loss: 0.0016 - val_psnr_metric: 31.7909
# Epoch 313/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.0437 - val_loss: 0.0015 - val_psnr_metric: 31.4323
# Epoch 314/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.0141 - val_loss: 0.0017 - val_psnr_metric: 30.8349
# Epoch 315/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.0651 - val_loss: 0.0017 - val_psnr_metric: 31.9817
# Epoch 316/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.2906 - val_loss: 0.0013 - val_psnr_metric: 31.6968
# Epoch 317/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.3836 - val_loss: 0.0015 - val_psnr_metric: 31.9549
# Epoch 318/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.9213 - val_loss: 0.0018 - val_psnr_metric: 30.8246
# Epoch 319/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.3955 - val_loss: 0.0019 - val_psnr_metric: 30.9125
# Epoch 320/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.2763 - val_loss: 0.0018 - val_psnr_metric: 31.9790
# Epoch 321/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.1521 - val_loss: 0.0018 - val_psnr_metric: 31.1468
# Epoch 322/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 31.1021 - val_loss: 0.0016 - val_psnr_metric: 31.9137
# Epoch 323/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.5340 - val_loss: 0.0018 - val_psnr_metric: 31.5247
# Epoch 324/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.8889 - val_loss: 0.0017 - val_psnr_metric: 31.2876
# Epoch 325/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.4842 - val_loss: 0.0014 - val_psnr_metric: 32.0781
# Epoch 326/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.2753 - val_loss: 0.0017 - val_psnr_metric: 30.9048
# Epoch 327/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.2210 - val_loss: 0.0018 - val_psnr_metric: 31.0043
# Epoch 328/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.1047 - val_loss: 0.0018 - val_psnr_metric: 30.8209
# Epoch 329/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.6536 - val_loss: 0.0022 - val_psnr_metric: 30.5048
# Epoch 330/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 30.8998 - val_loss: 0.0017 - val_psnr_metric: 31.0353
# Epoch 331/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.9641 - val_loss: 0.0017 - val_psnr_metric: 32.0039
# Epoch 332/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.7484 - val_loss: 0.0014 - val_psnr_metric: 31.6704
# Epoch 333/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.8756 - val_loss: 0.0016 - val_psnr_metric: 31.1767
# Epoch 334/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.7462 - val_loss: 0.0018 - val_psnr_metric: 30.9796
# Epoch 335/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.7753 - val_loss: 0.0018 - val_psnr_metric: 31.2237
# Epoch 336/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.9916 - val_loss: 0.0020 - val_psnr_metric: 30.4145
# Epoch 337/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.8095 - val_loss: 0.0015 - val_psnr_metric: 32.0447
# Epoch 338/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 30.9981 - val_loss: 0.0017 - val_psnr_metric: 31.5676
# Epoch 339/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 30.9513 - val_loss: 0.0018 - val_psnr_metric: 30.6747
# Epoch 340/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.0397 - val_loss: 0.0021 - val_psnr_metric: 30.3830
# Epoch 341/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.4722 - val_loss: 0.0021 - val_psnr_metric: 30.7867
# Epoch 342/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.4560 - val_loss: 0.0021 - val_psnr_metric: 30.2113
# Epoch 343/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 30.6133 - val_loss: 0.0021 - val_psnr_metric: 30.4376
# Epoch 344/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.4382 - val_loss: 0.0020 - val_psnr_metric: 31.3167
# Epoch 345/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.4477 - val_loss: 0.0019 - val_psnr_metric: 32.0135
# Epoch 346/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.3700 - val_loss: 0.0017 - val_psnr_metric: 31.7050
# Epoch 347/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.4571 - val_loss: 0.0019 - val_psnr_metric: 30.4220
# Epoch 348/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.5697 - val_loss: 0.0014 - val_psnr_metric: 31.9913
# Epoch 349/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.8753 - val_loss: 0.0018 - val_psnr_metric: 31.3158
# Epoch 350/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.1889 - val_loss: 0.0014 - val_psnr_metric: 32.6165
# Epoch 351/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.9106 - val_loss: 0.0014 - val_psnr_metric: 32.0673
# Epoch 352/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.5508 - val_loss: 0.0017 - val_psnr_metric: 30.9008
# Epoch 353/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.9868 - val_loss: 0.0017 - val_psnr_metric: 30.8084
# Epoch 354/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 31.3869 - val_loss: 0.0016 - val_psnr_metric: 31.4706
# Epoch 355/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.3762 - val_loss: 0.0015 - val_psnr_metric: 32.7519
# Epoch 356/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.4727 - val_loss: 0.0020 - val_psnr_metric: 30.3031
# Epoch 357/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.3461 - val_loss: 0.0015 - val_psnr_metric: 30.8977
# Epoch 358/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.0412 - val_loss: 0.0018 - val_psnr_metric: 31.4840
# Epoch 359/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.9204 - val_loss: 0.0016 - val_psnr_metric: 30.8378
# Epoch 360/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 31.0627 - val_loss: 0.0016 - val_psnr_metric: 31.4700
# Epoch 361/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.7390 - val_loss: 0.0016 - val_psnr_metric: 31.9566
# Epoch 362/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 31.4484 - val_loss: 0.0018 - val_psnr_metric: 31.0794
# Epoch 363/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.8516 - val_loss: 0.0015 - val_psnr_metric: 31.5230
# Epoch 364/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.8014 - val_loss: 0.0018 - val_psnr_metric: 30.8251
# Epoch 365/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.3605 - val_loss: 0.0016 - val_psnr_metric: 31.2066
# Epoch 366/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.8375 - val_loss: 0.0015 - val_psnr_metric: 32.2412
# Epoch 367/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.2420 - val_loss: 0.0019 - val_psnr_metric: 31.4458
# Epoch 368/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 31.3642 - val_loss: 0.0018 - val_psnr_metric: 31.9982
# Epoch 369/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.5906 - val_loss: 0.0017 - val_psnr_metric: 31.6940
# Epoch 370/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 31.6351 - val_loss: 0.0017 - val_psnr_metric: 31.5815
# Epoch 371/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.6024 - val_loss: 0.0017 - val_psnr_metric: 31.5996
# Epoch 372/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 32.1351 - val_loss: 0.0017 - val_psnr_metric: 31.1701
# Epoch 373/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.7418 - val_loss: 0.0015 - val_psnr_metric: 32.5953
# Epoch 374/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.6567 - val_loss: 0.0018 - val_psnr_metric: 31.3461
# Epoch 375/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.1752 - val_loss: 0.0016 - val_psnr_metric: 31.8123
# Epoch 376/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.1997 - val_loss: 0.0019 - val_psnr_metric: 30.9078
# Epoch 377/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.2061 - val_loss: 0.0014 - val_psnr_metric: 32.4977
# Epoch 378/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.7617 - val_loss: 0.0013 - val_psnr_metric: 32.4914
# Epoch 379/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.3749 - val_loss: 0.0015 - val_psnr_metric: 32.3229
# Epoch 380/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.4074 - val_loss: 0.0017 - val_psnr_metric: 31.1714
# Epoch 381/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.8577 - val_loss: 0.0012 - val_psnr_metric: 31.4895
# Epoch 382/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 31.9260 - val_loss: 0.0017 - val_psnr_metric: 30.8893
# Epoch 383/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.5545 - val_loss: 0.0016 - val_psnr_metric: 31.5612
# Epoch 384/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.4612 - val_loss: 0.0018 - val_psnr_metric: 31.0600
# Epoch 385/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.0183 - val_loss: 0.0015 - val_psnr_metric: 32.0401
# Epoch 386/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.0414 - val_loss: 0.0016 - val_psnr_metric: 31.1231
# Epoch 387/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 30.9904 - val_loss: 0.0017 - val_psnr_metric: 31.8280
# Epoch 388/1000
# 12/12 - 4s - loss: 0.0015 - psnr_metric: 32.4635 - val_loss: 0.0020 - val_psnr_metric: 30.6033
# Epoch 389/1000
# 12/12 - 4s - loss: 0.0016 - psnr_metric: 31.5451 - val_loss: 0.0016 - val_psnr_metric: 32.2989
# Epoch 390/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 31.0536 - val_loss: 0.0016 - val_psnr_metric: 32.1268
# Epoch 391/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.1452 - val_loss: 0.0019 - val_psnr_metric: 30.1834
# Epoch 392/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.4608 - val_loss: 0.0022 - val_psnr_metric: 29.9221
# Epoch 393/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.3523 - val_loss: 0.0019 - val_psnr_metric: 31.1708
# Epoch 394/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.6913 - val_loss: 0.0020 - val_psnr_metric: 31.5850
# Epoch 395/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.9238 - val_loss: 0.0016 - val_psnr_metric: 31.7711
# Epoch 396/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.3654 - val_loss: 0.0020 - val_psnr_metric: 30.6955
# Epoch 397/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 30.7469 - val_loss: 0.0019 - val_psnr_metric: 30.3720
# Epoch 398/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.5370 - val_loss: 0.0021 - val_psnr_metric: 30.4601
# Epoch 399/1000
# 12/12 - 4s - loss: 0.0016 - psnr_metric: 31.7758 - val_loss: 0.0017 - val_psnr_metric: 30.8994
# Epoch 400/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.6867 - val_loss: 0.0016 - val_psnr_metric: 31.3538
# Epoch 401/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.4888 - val_loss: 0.0017 - val_psnr_metric: 31.1686
# Epoch 402/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.4321 - val_loss: 0.0014 - val_psnr_metric: 31.3579
# Epoch 403/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 32.2032 - val_loss: 0.0017 - val_psnr_metric: 31.2432
# Epoch 404/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.5720 - val_loss: 0.0018 - val_psnr_metric: 31.4860
# Epoch 405/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.0049 - val_loss: 0.0018 - val_psnr_metric: 31.3816
# Epoch 406/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.6184 - val_loss: 0.0020 - val_psnr_metric: 30.9726
# Epoch 407/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.8258 - val_loss: 0.0020 - val_psnr_metric: 30.4683
# Epoch 408/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.1731 - val_loss: 0.0017 - val_psnr_metric: 32.1165
# Epoch 409/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.2863 - val_loss: 0.0019 - val_psnr_metric: 30.4119
# Epoch 410/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.6560 - val_loss: 0.0014 - val_psnr_metric: 32.2147
# Epoch 411/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 30.7586 - val_loss: 0.0018 - val_psnr_metric: 31.8359
# Epoch 412/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.6311 - val_loss: 0.0016 - val_psnr_metric: 32.0944
# Epoch 413/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.3495 - val_loss: 0.0017 - val_psnr_metric: 31.9868
# Epoch 414/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.5959 - val_loss: 0.0018 - val_psnr_metric: 31.1981
# Epoch 415/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.2510 - val_loss: 0.0017 - val_psnr_metric: 31.6590
# Epoch 416/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.6183 - val_loss: 0.0018 - val_psnr_metric: 31.1108
# Epoch 417/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 31.3501 - val_loss: 0.0016 - val_psnr_metric: 30.8247
# Epoch 418/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.4130 - val_loss: 0.0017 - val_psnr_metric: 30.9152
# Epoch 419/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.5323 - val_loss: 0.0019 - val_psnr_metric: 31.4238
# Epoch 420/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.0700 - val_loss: 0.0017 - val_psnr_metric: 30.8487
# Epoch 421/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.0839 - val_loss: 0.0018 - val_psnr_metric: 30.9517
# Epoch 422/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.5651 - val_loss: 0.0020 - val_psnr_metric: 31.0502
# Epoch 423/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.7418 - val_loss: 0.0017 - val_psnr_metric: 31.3754
# Epoch 424/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.2604 - val_loss: 0.0019 - val_psnr_metric: 31.0789
# Epoch 425/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.8323 - val_loss: 0.0016 - val_psnr_metric: 31.4108
# Epoch 426/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.6493 - val_loss: 0.0019 - val_psnr_metric: 31.2276
# Epoch 427/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.0203 - val_loss: 0.0016 - val_psnr_metric: 32.3009
# Epoch 428/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.8791 - val_loss: 0.0013 - val_psnr_metric: 32.3988
# Epoch 429/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 31.7922 - val_loss: 0.0016 - val_psnr_metric: 32.2603
# Epoch 430/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 31.9868 - val_loss: 0.0019 - val_psnr_metric: 31.0598
# Epoch 431/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.0844 - val_loss: 0.0019 - val_psnr_metric: 30.9058
# Epoch 432/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.2993 - val_loss: 0.0021 - val_psnr_metric: 30.8023
# Epoch 433/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 31.7911 - val_loss: 0.0017 - val_psnr_metric: 31.6303
# Epoch 434/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 31.8037 - val_loss: 0.0017 - val_psnr_metric: 32.3051
# Epoch 435/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 31.1710 - val_loss: 0.0018 - val_psnr_metric: 31.6022
# ...
# Epoch 856/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.7525 - val_loss: 0.0016 - val_psnr_metric: 32.0818
# Epoch 857/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.7867 - val_loss: 0.0016 - val_psnr_metric: 32.2734
# Epoch 858/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.3875 - val_loss: 0.0010 - val_psnr_metric: 33.8377
# Epoch 859/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.4217 - val_loss: 0.0016 - val_psnr_metric: 31.3802
# Epoch 860/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.7661 - val_loss: 0.0014 - val_psnr_metric: 32.4745
# Epoch 861/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.4724 - val_loss: 0.0012 - val_psnr_metric: 33.3301
# Epoch 862/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.3562 - val_loss: 0.0015 - val_psnr_metric: 32.8407
# Epoch 863/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.9827 - val_loss: 0.0017 - val_psnr_metric: 32.1160
# Epoch 864/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.4096 - val_loss: 0.0013 - val_psnr_metric: 33.3256
# Epoch 865/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.6448 - val_loss: 0.0016 - val_psnr_metric: 31.9443
# Epoch 866/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.6347 - val_loss: 0.0015 - val_psnr_metric: 32.1603
# Epoch 867/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.0795 - val_loss: 0.0016 - val_psnr_metric: 31.1946
# Epoch 868/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.6091 - val_loss: 0.0019 - val_psnr_metric: 31.1178
# Epoch 869/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 31.7921 - val_loss: 0.0016 - val_psnr_metric: 31.9937
# Epoch 870/1000
# 12/12 - 3s - loss: 0.0013 - psnr_metric: 33.1247 - val_loss: 0.0013 - val_psnr_metric: 33.1947
# Epoch 871/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.8669 - val_loss: 0.0014 - val_psnr_metric: 32.7679
# Epoch 872/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.6333 - val_loss: 0.0017 - val_psnr_metric: 31.2140
# Epoch 873/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 30.8412 - val_loss: 0.0018 - val_psnr_metric: 30.9918
# Epoch 874/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 31.7527 - val_loss: 0.0016 - val_psnr_metric: 30.7637
# Epoch 875/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 31.9900 - val_loss: 0.0016 - val_psnr_metric: 31.5340
# Epoch 876/1000
# 12/12 - 3s - loss: 0.0013 - psnr_metric: 32.1349 - val_loss: 0.0015 - val_psnr_metric: 31.9026
# Epoch 877/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.4301 - val_loss: 0.0016 - val_psnr_metric: 31.4703
# Epoch 878/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.8756 - val_loss: 0.0015 - val_psnr_metric: 32.1534
# Epoch 879/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 32.0787 - val_loss: 0.0016 - val_psnr_metric: 32.0682
# Epoch 880/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.9313 - val_loss: 0.0014 - val_psnr_metric: 32.5082
# Epoch 881/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.7632 - val_loss: 0.0017 - val_psnr_metric: 31.6451
# Epoch 882/1000
# 12/12 - 3s - loss: 0.0013 - psnr_metric: 32.2454 - val_loss: 0.0013 - val_psnr_metric: 32.7155
# Epoch 883/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 31.0194 - val_loss: 0.0018 - val_psnr_metric: 31.5297
# Epoch 884/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.2702 - val_loss: 0.0015 - val_psnr_metric: 31.8170
# Epoch 885/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.0091 - val_loss: 0.0014 - val_psnr_metric: 32.9185
# Epoch 886/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.9009 - val_loss: 0.0016 - val_psnr_metric: 32.2571
# Epoch 887/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.4151 - val_loss: 0.0014 - val_psnr_metric: 32.2418
# Epoch 888/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.3011 - val_loss: 0.0014 - val_psnr_metric: 31.8216
# Epoch 889/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.0366 - val_loss: 0.0015 - val_psnr_metric: 31.9809
# Epoch 890/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.6860 - val_loss: 0.0018 - val_psnr_metric: 32.5324
# Epoch 891/1000
# 12/12 - 3s - loss: 0.0013 - psnr_metric: 32.5932 - val_loss: 0.0015 - val_psnr_metric: 31.7386
# Epoch 892/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 31.3411 - val_loss: 0.0013 - val_psnr_metric: 33.0676
# Epoch 893/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.7012 - val_loss: 0.0017 - val_psnr_metric: 32.1179
# Epoch 894/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.7313 - val_loss: 0.0016 - val_psnr_metric: 32.2395
# Epoch 895/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.3904 - val_loss: 0.0013 - val_psnr_metric: 32.2210
# Epoch 896/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.7528 - val_loss: 0.0016 - val_psnr_metric: 32.8620
# Epoch 897/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.0604 - val_loss: 0.0017 - val_psnr_metric: 32.5599
# Epoch 898/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 32.1479 - val_loss: 0.0014 - val_psnr_metric: 33.0377
# Epoch 899/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.2955 - val_loss: 0.0014 - val_psnr_metric: 33.3463
# Epoch 900/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.7431 - val_loss: 0.0016 - val_psnr_metric: 32.3909
# Epoch 901/1000
# 12/12 - 3s - loss: 0.0019 - psnr_metric: 31.8164 - val_loss: 0.0011 - val_psnr_metric: 33.9105
# Epoch 902/1000
# 12/12 - 4s - loss: 0.0015 - psnr_metric: 32.7780 - val_loss: 0.0013 - val_psnr_metric: 32.5589
# Epoch 903/1000
# 12/12 - 4s - loss: 0.0016 - psnr_metric: 32.4485 - val_loss: 0.0015 - val_psnr_metric: 32.2635
# Epoch 904/1000
# 12/12 - 4s - loss: 0.0014 - psnr_metric: 32.7810 - val_loss: 0.0015 - val_psnr_metric: 31.9422
# Epoch 905/1000
# 12/12 - 3s - loss: 0.0013 - psnr_metric: 33.3817 - val_loss: 0.0016 - val_psnr_metric: 32.2736
# Epoch 906/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.6749 - val_loss: 0.0012 - val_psnr_metric: 32.8483
# Epoch 907/1000
# 12/12 - 3s - loss: 0.0020 - psnr_metric: 31.2307 - val_loss: 0.0016 - val_psnr_metric: 30.9661
# Epoch 908/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.4497 - val_loss: 0.0016 - val_psnr_metric: 31.4028
# Epoch 909/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.6281 - val_loss: 0.0013 - val_psnr_metric: 32.8720
# Epoch 910/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.3582 - val_loss: 0.0016 - val_psnr_metric: 31.9558
# Epoch 911/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 31.8732 - val_loss: 0.0014 - val_psnr_metric: 32.6709
# Epoch 912/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.1113 - val_loss: 0.0015 - val_psnr_metric: 32.8855
# Epoch 913/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.5978 - val_loss: 0.0015 - val_psnr_metric: 31.4496
# Epoch 914/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.5479 - val_loss: 0.0013 - val_psnr_metric: 32.1487
# Epoch 915/1000
# 12/12 - 3s - loss: 0.0013 - psnr_metric: 32.9208 - val_loss: 0.0015 - val_psnr_metric: 31.7548
# Epoch 916/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.8029 - val_loss: 0.0016 - val_psnr_metric: 31.3449
# Epoch 917/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.4837 - val_loss: 0.0014 - val_psnr_metric: 32.3418
# Epoch 918/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.9319 - val_loss: 0.0012 - val_psnr_metric: 32.6506
# Epoch 919/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.5934 - val_loss: 0.0017 - val_psnr_metric: 33.0386
# Epoch 920/1000
# 12/12 - 3s - loss: 0.0013 - psnr_metric: 32.5097 - val_loss: 0.0014 - val_psnr_metric: 32.7896
# Epoch 921/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.8978 - val_loss: 0.0015 - val_psnr_metric: 32.3487
# Epoch 922/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.2502 - val_loss: 0.0017 - val_psnr_metric: 32.6797
# Epoch 923/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.2773 - val_loss: 0.0016 - val_psnr_metric: 32.1553
# Epoch 924/1000
# 12/12 - 3s - loss: 0.0012 - psnr_metric: 33.6427 - val_loss: 0.0014 - val_psnr_metric: 33.5690
# Epoch 925/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 32.9034 - val_loss: 0.0019 - val_psnr_metric: 31.4095
# Epoch 926/1000
# 12/12 - 3s - loss: 0.0013 - psnr_metric: 33.1813 - val_loss: 0.0015 - val_psnr_metric: 32.0446
# Epoch 927/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.2908 - val_loss: 0.0017 - val_psnr_metric: 31.9716
# Epoch 928/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.4555 - val_loss: 0.0014 - val_psnr_metric: 31.8091
# Epoch 929/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 32.5100 - val_loss: 0.0016 - val_psnr_metric: 32.1311
# Epoch 930/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 32.0638 - val_loss: 0.0014 - val_psnr_metric: 32.4722
# Epoch 931/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.2092 - val_loss: 0.0013 - val_psnr_metric: 33.6667
# Epoch 932/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.6266 - val_loss: 0.0014 - val_psnr_metric: 32.6316
# Epoch 933/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.5433 - val_loss: 0.0015 - val_psnr_metric: 32.1944
# Epoch 934/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 32.0140 - val_loss: 0.0015 - val_psnr_metric: 31.6669
# Epoch 935/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.6456 - val_loss: 0.0014 - val_psnr_metric: 32.6707
# Epoch 936/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.0636 - val_loss: 0.0019 - val_psnr_metric: 31.4005
# Epoch 937/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.5633 - val_loss: 0.0015 - val_psnr_metric: 32.2674
# Epoch 938/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.4655 - val_loss: 0.0012 - val_psnr_metric: 33.4565
# Epoch 939/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.6956 - val_loss: 0.0014 - val_psnr_metric: 32.6756
# Epoch 940/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.3282 - val_loss: 0.0014 - val_psnr_metric: 32.8521
# Epoch 941/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.5143 - val_loss: 0.0016 - val_psnr_metric: 32.3816
# Epoch 942/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.3234 - val_loss: 0.0014 - val_psnr_metric: 32.5889
# Epoch 943/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 33.3766 - val_loss: 0.0014 - val_psnr_metric: 31.9975
# Epoch 944/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.4109 - val_loss: 0.0012 - val_psnr_metric: 33.4909
# Epoch 945/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.3569 - val_loss: 0.0014 - val_psnr_metric: 32.3502
# Epoch 946/1000
# 12/12 - 3s - loss: 0.0012 - psnr_metric: 33.0922 - val_loss: 0.0018 - val_psnr_metric: 31.3585
# Epoch 947/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.9651 - val_loss: 0.0016 - val_psnr_metric: 31.0300
# Epoch 948/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.9685 - val_loss: 0.0014 - val_psnr_metric: 32.9144
# Epoch 949/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.2757 - val_loss: 0.0018 - val_psnr_metric: 32.0877
# Epoch 950/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.9277 - val_loss: 0.0015 - val_psnr_metric: 32.1281
# Epoch 951/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.4985 - val_loss: 0.0015 - val_psnr_metric: 32.5183
# Epoch 952/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.5159 - val_loss: 0.0016 - val_psnr_metric: 31.4415
# Epoch 953/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.9348 - val_loss: 0.0018 - val_psnr_metric: 32.4517
# Epoch 954/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.4579 - val_loss: 0.0016 - val_psnr_metric: 31.3206
# Epoch 955/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.8264 - val_loss: 0.0015 - val_psnr_metric: 31.7918
# Epoch 956/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.9272 - val_loss: 0.0015 - val_psnr_metric: 32.6263
# Epoch 957/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.8148 - val_loss: 0.0013 - val_psnr_metric: 31.6231
# Epoch 958/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.6936 - val_loss: 0.0016 - val_psnr_metric: 31.4968
# Epoch 959/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.1716 - val_loss: 0.0017 - val_psnr_metric: 31.9430
# Epoch 960/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.3697 - val_loss: 0.0015 - val_psnr_metric: 31.6085
# Epoch 961/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.0059 - val_loss: 0.0016 - val_psnr_metric: 31.6818
# Epoch 962/1000
# 12/12 - 3s - loss: 0.0013 - psnr_metric: 32.7855 - val_loss: 0.0017 - val_psnr_metric: 32.0034
# Epoch 963/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.5378 - val_loss: 0.0017 - val_psnr_metric: 30.9054
# Epoch 964/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.0238 - val_loss: 0.0012 - val_psnr_metric: 32.4961
# Epoch 965/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 31.8651 - val_loss: 0.0016 - val_psnr_metric: 32.7024
# Epoch 966/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 31.5043 - val_loss: 0.0015 - val_psnr_metric: 31.3615
# Epoch 967/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.5439 - val_loss: 0.0014 - val_psnr_metric: 32.4646
# Epoch 968/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.8207 - val_loss: 0.0016 - val_psnr_metric: 31.7123
# Epoch 969/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.1238 - val_loss: 0.0015 - val_psnr_metric: 32.5737
# Epoch 970/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.4699 - val_loss: 0.0013 - val_psnr_metric: 32.7882
# Epoch 971/1000
# 12/12 - 3s - loss: 0.0012 - psnr_metric: 33.4321 - val_loss: 0.0014 - val_psnr_metric: 32.9472
# Epoch 972/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.1779 - val_loss: 0.0016 - val_psnr_metric: 32.2057
# Epoch 973/1000
# 12/12 - 3s - loss: 0.0013 - psnr_metric: 33.3659 - val_loss: 0.0012 - val_psnr_metric: 33.6664
# Epoch 974/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.3943 - val_loss: 0.0015 - val_psnr_metric: 32.4110
# Epoch 975/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.9416 - val_loss: 0.0013 - val_psnr_metric: 33.3182
# Epoch 976/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.7276 - val_loss: 0.0017 - val_psnr_metric: 32.8755
# Epoch 977/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.9596 - val_loss: 0.0011 - val_psnr_metric: 33.8280
# Epoch 978/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.8211 - val_loss: 0.0010 - val_psnr_metric: 34.1845
# Epoch 979/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.4199 - val_loss: 0.0013 - val_psnr_metric: 33.8044
# Epoch 980/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.8378 - val_loss: 0.0014 - val_psnr_metric: 32.0532
# Epoch 981/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 31.7102 - val_loss: 0.0016 - val_psnr_metric: 31.6443
# Epoch 982/1000
# 12/12 - 3s - loss: 0.0016 - psnr_metric: 32.4391 - val_loss: 0.0013 - val_psnr_metric: 32.6119
# Epoch 983/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.3339 - val_loss: 0.0013 - val_psnr_metric: 32.4757
# Epoch 984/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 32.3442 - val_loss: 0.0014 - val_psnr_metric: 33.7795
# Epoch 985/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.2020 - val_loss: 0.0014 - val_psnr_metric: 32.9853
# Epoch 986/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.8050 - val_loss: 0.0014 - val_psnr_metric: 32.4624
# Epoch 987/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.6198 - val_loss: 0.0015 - val_psnr_metric: 32.0779
# Epoch 988/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.6389 - val_loss: 0.0014 - val_psnr_metric: 32.5118
# Epoch 989/1000
# 12/12 - 4s - loss: 0.0014 - psnr_metric: 32.8240 - val_loss: 0.0015 - val_psnr_metric: 32.3075
# Epoch 990/1000
# 12/12 - 3s - loss: 0.0018 - psnr_metric: 31.9718 - val_loss: 0.0018 - val_psnr_metric: 31.1393
# Epoch 991/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.3825 - val_loss: 0.0013 - val_psnr_metric: 33.1497
# Epoch 992/1000
# 12/12 - 3s - loss: 0.0017 - psnr_metric: 31.8650 - val_loss: 0.0015 - val_psnr_metric: 32.5664
# Epoch 993/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 31.8621 - val_loss: 0.0015 - val_psnr_metric: 32.3865
# Epoch 994/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.6014 - val_loss: 0.0014 - val_psnr_metric: 32.3149
# Epoch 995/1000
# 12/12 - 3s - loss: 0.0013 - psnr_metric: 33.2409 - val_loss: 0.0016 - val_psnr_metric: 32.0501
# Epoch 996/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.1442 - val_loss: 0.0015 - val_psnr_metric: 31.9364
# Epoch 997/1000
# 12/12 - 3s - loss: 0.0014 - psnr_metric: 32.8173 - val_loss: 0.0015 - val_psnr_metric: 32.4283
# Epoch 998/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.7882 - val_loss: 0.0013 - val_psnr_metric: 32.6776
# Epoch 999/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.2986 - val_loss: 0.0015 - val_psnr_metric: 32.9123
# Epoch 1000/1000
# 12/12 - 3s - loss: 0.0015 - psnr_metric: 32.4111 - val_loss: 0.0014 - val_psnr_metric: 32.6642

# %% [markdown]
# - `Dataset`를 이용한 학습은 `fit()` 함수 대신 `fit_generator()` 함수를 사용합니다.
# - `Dataset`에 `repeat()` 함수를 사용했기 때문에 한 번의 에포크에 몇 개의 데이터를 학습시킬지를 지정하는 `steps_per_epoch`인수를 설정해야 합니다.
# - `batch size`가 16이기 때문에 `steps_per_epoch`는 `len(train_path)//16`으로 훈련 데이터의 크기를 `batch size`로 나눕니다.
#   + //는 결과가 정수로 나오는 나눗셈을 의미합니다. 예를 들면 200//16의 결과는 12가 됩니다.
# - `verbose=2`의 의미니느 출력제한에 걸리지 않도록 하며, 진행 상황 애니메이션은 생략하고 각 에포크의 결과만 출력합니다.
# - 학습 결과, 훈련 데이터의 `PSNR`은 31~32, 검증데이터의 29-32정도가 나옵니다.

# %% [markdown]
# ### (9) 네트워크 학습 결과 확인
# 학습 겨로가를 확인합니다.

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['psnr_metric'], 'b-', label='psnr')
plt.plot(history.history['val_psnr_metric'], 'r--', label='val_psnr')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# PSNR 수치 모두 학습할수록 증가하는 경향을 보입니다. 이렇게 학습된 데이터가 실제 이미지를 어떻게 복원하는지 확인합니다.

# %%
img = tf.io.read_file(test_path[0])
img = tf.image.decode_jpeg(img, channels=3)
hr = tf.image.convert_image_dtype(img, tf.float32)

lr = tf.image.resize(hr, [hr.shape[0]//2, hr.shape[1]//2])
lr = tf.image.resize(lr, [hr.shape[0], hr.shape[1]])
predict_hr=model.predict(np.expand_dims(lr, axis=0))

print(tf.image.psnr(np.squeeze(predict_hr, axis=0), hr, max_val=1.0))
print(tf.image.psnr(lr, hr, max_val=1.0))
# Out:
# tf.Tensor(26.110872, shape=(), dtype=float32)
# tf.Tensor(24.853115, shape=(), dtype=float32)

# %% [markdown]
# ### (10) 테스트 이미지에 대한 초해상도 결과 확인
# - 테스트 데이터 중 첫 번째 이미지를 불러와서 저해상도 버전을 만든 다음 `REDNet-30` 네트워크에 통과시켜서 복원 이미지를 얻어냅니다.
# - 결과에서 `PSNR` 점수는 복원 이미지가 저해상도 이미지보다 아주 살짝 높은 것으로 나옵니다.
# - 이미지를 출력합니다.

# %%
plt.figure(figsize=(16,4))
plt.subplot(1,3,1)
plt.imshow(hr)
plt.title('original - hr')

plt.subplot(1,3,2)
plt.imshow(lr)
plt.title('lr')

plt.subplot(1,3,3)
plt.imshow(np.squeeze(predict_hr, axis=0))
plt.title('sr')

plt.show()

# %% [markdown]
# - 첫번째 사진이 이미지의 원본이고, 두번째 사진이 저해상도, 세번째 줄이 복원된 이미지입니다.
# - 이 작업의 성능을 비교하기 위해 `Set5`라는 데이터세트가 있습니다. 이 중에서도 자주 쓰이는 나비의 사진을 불러와서 확인합니다.

# %%
image_path = tf.keras.utils.get_file('butterfly.png', 'http://bit.ly/2oAOxgH')
img = tf.io.read_file(image_path)
img = tf.image.decode_jpeg(img, channels=3)
hr = tf.image.convert_image_dtype(img, tf.float32)

lr = tf.image.resize(hr, [hr.shape[0]//4, hr.shape[1]//4])
lr = tf.image.resize(lr, [hr.shape[0], hr.shape[1]])
predict_hr = model.predict(np.expand_dims(lr, axis=0))

print(tf.image.psnr(np.squeeze(predict_hr, axis=0), hr, max_val=1.0))
print(tf.image.psnr(lr, hr, max_val=1.0))


plt.figure(figsize=(16,6))
plt.subplot(1, 3, 1)
plt.imshow(hr)
plt.title('original - hr')

plt.subplot(1, 3, 2)
plt.imshow(lr)
plt.title('lr')

plt.subplot(1, 3, 3)
plt.imshow(np.squeeze(predict_hr, axis=0))
plt.title('sr')
# Out:
# Downloading data from http://bit.ly/2oAOxgH
# 131072/127529 [==============================] - 0s 0us/step
# tf.Tensor(20.3429, shape=(), dtype=float32)
# tf.Tensor(20.217585, shape=(), dtype=float32)
# Text(0.5, 1.0, 'sr')

# %% [markdown]
# - 벤치마크답게 `PSNR` 점수에서 성능 차이가 뚜렷하게 드러납니다.
# - 조금 더 어려운 과제로는 확대 비율을 늘려볼 수 있습니다. 현재는 2배인데, 이를 4배로 늘려봅니다.

# %% [markdown]
# ### (11) 확대비율 4배로 수정, 이미지 보강 REDNet-30 네트워크 학습
# `Dataset`에서는 쉽게 이미지 보강을 할 수 있습니다. 이미지에서 랜덤한 부분을 잘라서 고해상도와 저해상도 버전을 추출하던 `get_hr_and_lr()` 함수를 다음과 같이 바꿉니다.

# %%
import random
def get_hr_and_lr_flip_s4(image_path):
  img = tf.io.read_file(image_path)
  img = tf.image.decode_jpeg(img, channels=3)
  img = tf.image.convert_image_dtype(img, tf.float32)

  hr = tf.image.random_crop(img, [50,50,3])
  lr = tf.image.resize(hr, [12, 12])
  lr = tf.image.resize(lr, [50,50])

  if random.random() < 0.25:
    hr = tf.image.flip_left_right(hr)
    lr = tf.image.flip_left_right(lr)
  if random.random() < 0.25:
    hr = tf.image.flip_up_down(hr)
    lr = tf.image.flip_up_down(lr)

  return lr, hr

# %% [markdown]
# - 앞부분은 축소/확대 비율을 2배에서 4배로 바꾸는 부분을 제외하면 `get_hr_and_lr()` 함수와 같고, 뒤쪽에서 `25%`의 확률로 좌우 반전, 또 `25%`의 확률로 상하 반전을 시켜줍니다.
# - 결과적으로 `Dataset`을 다시 정의하고 바뀐 함수를 적용합니다.

# %% [markdown]
# ### (12) REDNet-30 네트워크 학습

# %%
train_dataset = tf.data.Dataset.list_files(train_path)
train_dataset = train_dataset.map(get_hr_and_lr_flip_s4)
train_dataset = train_dataset.repeat()
train_dataset = train_dataset.batch(16)

valid_dataset = tf.data.Dataset.list_files(valid_path)
valid_dataset = valid_dataset.map(get_hr_and_lr_flip_s4)
valid_dataset = valid_dataset.repeat()
valid_dataset = valid_dataset.batch(1)

model = REDNet(15)
model.compile(optimizer=tf.optimizers.Adam(0.0001), loss='mse', metrics=[psnr_metric])

history = model.fit_generator(train_dataset, 
                              epochs=4000, 
                              steps_per_epoch=len(train_path)//16, 
                              validation_data=valid_dataset, 
                              validation_steps=len(valid_path), 
                              verbose=2)
# Out:
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.3362 - val_loss: 0.0050 - val_psnr_metric: 27.4308
# Epoch 3548/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 26.8918 - val_loss: 0.0045 - val_psnr_metric: 26.7091
# Epoch 3549/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.3886 - val_loss: 0.0054 - val_psnr_metric: 26.1654
# Epoch 3550/4000
# 12/12 - 3s - loss: 0.0041 - psnr_metric: 27.7600 - val_loss: 0.0057 - val_psnr_metric: 25.9824
# Epoch 3551/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 27.6858 - val_loss: 0.0052 - val_psnr_metric: 25.7605
# Epoch 3552/4000
# 12/12 - 3s - loss: 0.0054 - psnr_metric: 26.9592 - val_loss: 0.0054 - val_psnr_metric: 26.2720
# Epoch 3553/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.9646 - val_loss: 0.0055 - val_psnr_metric: 26.3445
# Epoch 3554/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 28.0133 - val_loss: 0.0056 - val_psnr_metric: 26.3183
# Epoch 3555/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 26.8718 - val_loss: 0.0058 - val_psnr_metric: 25.4404
# Epoch 3556/4000
# 12/12 - 3s - loss: 0.0041 - psnr_metric: 27.5578 - val_loss: 0.0046 - val_psnr_metric: 26.9233
# Epoch 3557/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.4061 - val_loss: 0.0052 - val_psnr_metric: 26.7492
# Epoch 3558/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.6494 - val_loss: 0.0047 - val_psnr_metric: 26.6976
# Epoch 3559/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.3799 - val_loss: 0.0053 - val_psnr_metric: 26.1021
# Epoch 3560/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.2778 - val_loss: 0.0057 - val_psnr_metric: 26.4114
# Epoch 3561/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.3680 - val_loss: 0.0051 - val_psnr_metric: 26.3818
# Epoch 3562/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 26.9723 - val_loss: 0.0053 - val_psnr_metric: 25.9009
# Epoch 3563/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 25.8588 - val_loss: 0.0050 - val_psnr_metric: 26.1505
# Epoch 3564/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.1705 - val_loss: 0.0047 - val_psnr_metric: 26.6148
# Epoch 3565/4000
# 12/12 - 3s - loss: 0.0054 - psnr_metric: 27.0460 - val_loss: 0.0051 - val_psnr_metric: 26.3668
# Epoch 3566/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.2382 - val_loss: 0.0051 - val_psnr_metric: 25.8037
# Epoch 3567/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.5985 - val_loss: 0.0051 - val_psnr_metric: 27.1166
# Epoch 3568/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.9138 - val_loss: 0.0053 - val_psnr_metric: 26.6582
# Epoch 3569/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.3911 - val_loss: 0.0051 - val_psnr_metric: 26.0259
# Epoch 3570/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.6388 - val_loss: 0.0060 - val_psnr_metric: 25.5846
# Epoch 3571/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 26.5000 - val_loss: 0.0057 - val_psnr_metric: 26.1683
# Epoch 3572/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.4428 - val_loss: 0.0058 - val_psnr_metric: 25.7732
# Epoch 3573/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.4406 - val_loss: 0.0059 - val_psnr_metric: 25.0169
# Epoch 3574/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.3291 - val_loss: 0.0052 - val_psnr_metric: 26.3023
# Epoch 3575/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.4199 - val_loss: 0.0049 - val_psnr_metric: 26.6721
# Epoch 3576/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.4549 - val_loss: 0.0056 - val_psnr_metric: 25.4618
# Epoch 3577/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.0357 - val_loss: 0.0060 - val_psnr_metric: 25.4783
# Epoch 3578/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.4419 - val_loss: 0.0045 - val_psnr_metric: 26.7718
# Epoch 3579/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.7028 - val_loss: 0.0044 - val_psnr_metric: 26.6910
# Epoch 3580/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 28.2487 - val_loss: 0.0045 - val_psnr_metric: 27.4208
# Epoch 3581/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.2903 - val_loss: 0.0050 - val_psnr_metric: 27.0175
# Epoch 3582/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 26.4786 - val_loss: 0.0058 - val_psnr_metric: 25.3999
# Epoch 3583/4000
# 12/12 - 3s - loss: 0.0054 - psnr_metric: 27.1858 - val_loss: 0.0058 - val_psnr_metric: 25.6804
# Epoch 3584/4000
# 12/12 - 3s - loss: 0.0055 - psnr_metric: 26.5549 - val_loss: 0.0052 - val_psnr_metric: 26.4467
# Epoch 3585/4000
# 12/12 - 3s - loss: 0.0057 - psnr_metric: 26.5613 - val_loss: 0.0053 - val_psnr_metric: 25.8678
# Epoch 3586/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 26.4140 - val_loss: 0.0049 - val_psnr_metric: 26.4536
# Epoch 3587/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 26.6547 - val_loss: 0.0058 - val_psnr_metric: 26.3746
# Epoch 3588/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 26.7129 - val_loss: 0.0046 - val_psnr_metric: 26.5275
# Epoch 3589/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.2010 - val_loss: 0.0053 - val_psnr_metric: 26.3359
# Epoch 3590/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 26.7878 - val_loss: 0.0051 - val_psnr_metric: 25.6115
# Epoch 3591/4000
# 12/12 - 3s - loss: 0.0054 - psnr_metric: 26.3980 - val_loss: 0.0050 - val_psnr_metric: 25.7505
# Epoch 3592/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.2521 - val_loss: 0.0055 - val_psnr_metric: 25.9280
# Epoch 3593/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 27.0867 - val_loss: 0.0052 - val_psnr_metric: 26.2127
# Epoch 3594/4000
# 12/12 - 3s - loss: 0.0040 - psnr_metric: 27.7130 - val_loss: 0.0049 - val_psnr_metric: 27.1862
# Epoch 3595/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.3354 - val_loss: 0.0060 - val_psnr_metric: 26.1566
# Epoch 3596/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 26.6414 - val_loss: 0.0058 - val_psnr_metric: 25.6326
# Epoch 3597/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 26.6347 - val_loss: 0.0052 - val_psnr_metric: 26.7401
# Epoch 3598/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.1470 - val_loss: 0.0049 - val_psnr_metric: 26.5370
# Epoch 3599/4000
# 12/12 - 3s - loss: 0.0056 - psnr_metric: 26.3350 - val_loss: 0.0048 - val_psnr_metric: 26.5672
# Epoch 3600/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.8538 - val_loss: 0.0048 - val_psnr_metric: 25.7330
# Epoch 3601/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 26.4646 - val_loss: 0.0053 - val_psnr_metric: 26.2918
# Epoch 3602/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 27.1187 - val_loss: 0.0052 - val_psnr_metric: 25.3421
# Epoch 3603/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 27.5906 - val_loss: 0.0059 - val_psnr_metric: 26.2372
# Epoch 3604/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.0619 - val_loss: 0.0047 - val_psnr_metric: 26.0418
# Epoch 3605/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.7669 - val_loss: 0.0057 - val_psnr_metric: 25.3751
# Epoch 3606/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.4956 - val_loss: 0.0051 - val_psnr_metric: 25.9506
# Epoch 3607/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.0872 - val_loss: 0.0050 - val_psnr_metric: 26.6918
# Epoch 3608/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.7518 - val_loss: 0.0059 - val_psnr_metric: 26.3473
# Epoch 3609/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.5671 - val_loss: 0.0053 - val_psnr_metric: 25.6273
# Epoch 3610/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.6562 - val_loss: 0.0046 - val_psnr_metric: 26.4342
# Epoch 3611/4000
# 12/12 - 3s - loss: 0.0041 - psnr_metric: 28.0236 - val_loss: 0.0048 - val_psnr_metric: 26.8239
# Epoch 3612/4000
# 12/12 - 3s - loss: 0.0038 - psnr_metric: 27.4791 - val_loss: 0.0048 - val_psnr_metric: 26.2177
# Epoch 3613/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.2288 - val_loss: 0.0049 - val_psnr_metric: 27.1313
# Epoch 3614/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 28.3329 - val_loss: 0.0054 - val_psnr_metric: 25.3119
# Epoch 3615/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.5050 - val_loss: 0.0059 - val_psnr_metric: 25.9515
# Epoch 3616/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 28.1614 - val_loss: 0.0054 - val_psnr_metric: 25.8490
# Epoch 3617/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.2888 - val_loss: 0.0049 - val_psnr_metric: 26.3278
# Epoch 3618/4000
# 12/12 - 3s - loss: 0.0055 - psnr_metric: 26.8576 - val_loss: 0.0053 - val_psnr_metric: 26.2047
# Epoch 3619/4000
# 12/12 - 3s - loss: 0.0041 - psnr_metric: 27.8542 - val_loss: 0.0056 - val_psnr_metric: 25.8757
# Epoch 3620/4000
# 12/12 - 3s - loss: 0.0055 - psnr_metric: 26.6216 - val_loss: 0.0050 - val_psnr_metric: 26.2773
# Epoch 3621/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.8633 - val_loss: 0.0049 - val_psnr_metric: 26.9020
# Epoch 3622/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 26.8784 - val_loss: 0.0057 - val_psnr_metric: 26.5709
# Epoch 3623/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.8419 - val_loss: 0.0058 - val_psnr_metric: 26.6896
# Epoch 3624/4000
# 12/12 - 3s - loss: 0.0055 - psnr_metric: 27.0498 - val_loss: 0.0053 - val_psnr_metric: 25.7943
# Epoch 3625/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.2909 - val_loss: 0.0051 - val_psnr_metric: 26.6069
# Epoch 3626/4000
# 12/12 - 3s - loss: 0.0054 - psnr_metric: 26.3865 - val_loss: 0.0044 - val_psnr_metric: 26.5280
# Epoch 3627/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.2379 - val_loss: 0.0053 - val_psnr_metric: 27.0115
# Epoch 3628/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.3574 - val_loss: 0.0050 - val_psnr_metric: 25.5344
# Epoch 3629/4000
# 12/12 - 3s - loss: 0.0041 - psnr_metric: 27.7829 - val_loss: 0.0051 - val_psnr_metric: 26.6238
# Epoch 3630/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.8624 - val_loss: 0.0061 - val_psnr_metric: 25.4547
# Epoch 3631/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 27.1922 - val_loss: 0.0062 - val_psnr_metric: 25.3998
# Epoch 3632/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.6214 - val_loss: 0.0048 - val_psnr_metric: 27.0945
# Epoch 3633/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.6817 - val_loss: 0.0062 - val_psnr_metric: 25.6085
# Epoch 3634/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 27.0784 - val_loss: 0.0052 - val_psnr_metric: 26.0786
# Epoch 3635/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 27.8144 - val_loss: 0.0056 - val_psnr_metric: 25.5863
# Epoch 3636/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.7010 - val_loss: 0.0057 - val_psnr_metric: 26.3128
# Epoch 3637/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.1381 - val_loss: 0.0053 - val_psnr_metric: 26.4503
# Epoch 3638/4000
# 12/12 - 3s - loss: 0.0057 - psnr_metric: 26.2592 - val_loss: 0.0053 - val_psnr_metric: 25.9873
# Epoch 3639/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 26.6961 - val_loss: 0.0051 - val_psnr_metric: 26.4731
# Epoch 3640/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.2552 - val_loss: 0.0053 - val_psnr_metric: 25.8307
# Epoch 3641/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 27.8712 - val_loss: 0.0056 - val_psnr_metric: 26.0721
# Epoch 3642/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 26.9519 - val_loss: 0.0054 - val_psnr_metric: 26.8245
# Epoch 3643/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 26.9480 - val_loss: 0.0058 - val_psnr_metric: 25.5681
# Epoch 3644/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 26.7784 - val_loss: 0.0050 - val_psnr_metric: 25.8517
# Epoch 3645/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 26.8578 - val_loss: 0.0048 - val_psnr_metric: 27.1597
# Epoch 3646/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.3354 - val_loss: 0.0056 - val_psnr_metric: 25.5936
# Epoch 3647/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.4755 - val_loss: 0.0060 - val_psnr_metric: 25.2416
# Epoch 3648/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.1735 - val_loss: 0.0055 - val_psnr_metric: 26.2796
# Epoch 3649/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.4383 - val_loss: 0.0050 - val_psnr_metric: 26.0371
# Epoch 3650/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 26.7493 - val_loss: 0.0046 - val_psnr_metric: 26.8811
# Epoch 3651/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 26.7863 - val_loss: 0.0056 - val_psnr_metric: 25.7105
# Epoch 3652/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.0637 - val_loss: 0.0051 - val_psnr_metric: 26.1275
# Epoch 3653/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.2788 - val_loss: 0.0052 - val_psnr_metric: 25.4619
# Epoch 3654/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 28.0914 - val_loss: 0.0049 - val_psnr_metric: 26.9469
# Epoch 3655/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.9396 - val_loss: 0.0049 - val_psnr_metric: 26.6787
# Epoch 3656/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.2459 - val_loss: 0.0047 - val_psnr_metric: 27.1952
# Epoch 3657/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.9325 - val_loss: 0.0052 - val_psnr_metric: 26.2318
# Epoch 3658/4000
# 12/12 - 3s - loss: 0.0054 - psnr_metric: 26.2800 - val_loss: 0.0059 - val_psnr_metric: 25.9930
# Epoch 3659/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.1853 - val_loss: 0.0057 - val_psnr_metric: 25.4098
# Epoch 3660/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.4708 - val_loss: 0.0056 - val_psnr_metric: 25.5714
# Epoch 3661/4000
# 12/12 - 3s - loss: 0.0057 - psnr_metric: 26.4909 - val_loss: 0.0048 - val_psnr_metric: 26.3619
# Epoch 3662/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 27.3913 - val_loss: 0.0049 - val_psnr_metric: 26.7811
# Epoch 3663/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.0137 - val_loss: 0.0057 - val_psnr_metric: 25.8158
# Epoch 3664/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 26.8978 - val_loss: 0.0057 - val_psnr_metric: 25.7777
# Epoch 3665/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.2947 - val_loss: 0.0060 - val_psnr_metric: 24.9877
# Epoch 3666/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.3812 - val_loss: 0.0056 - val_psnr_metric: 26.1622
# Epoch 3667/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 26.9550 - val_loss: 0.0057 - val_psnr_metric: 26.0076
# Epoch 3668/4000
# 12/12 - 3s - loss: 0.0054 - psnr_metric: 27.1576 - val_loss: 0.0043 - val_psnr_metric: 26.6664
# Epoch 3669/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.6525 - val_loss: 0.0054 - val_psnr_metric: 25.7840
# Epoch 3670/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 27.6334 - val_loss: 0.0053 - val_psnr_metric: 26.7149
# Epoch 3671/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.1591 - val_loss: 0.0044 - val_psnr_metric: 26.2792
# Epoch 3672/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.1034 - val_loss: 0.0050 - val_psnr_metric: 26.0546
# Epoch 3673/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.0876 - val_loss: 0.0064 - val_psnr_metric: 25.7123
# Epoch 3674/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.5165 - val_loss: 0.0058 - val_psnr_metric: 25.7688
# Epoch 3675/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.5016 - val_loss: 0.0054 - val_psnr_metric: 26.0091
# Epoch 3676/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.6524 - val_loss: 0.0062 - val_psnr_metric: 25.3219
# Epoch 3677/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.6002 - val_loss: 0.0053 - val_psnr_metric: 26.8297
# Epoch 3678/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.3149 - val_loss: 0.0050 - val_psnr_metric: 26.3491
# Epoch 3679/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 26.8941 - val_loss: 0.0050 - val_psnr_metric: 26.5313
# Epoch 3680/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.6061 - val_loss: 0.0046 - val_psnr_metric: 26.4731
# Epoch 3681/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.8305 - val_loss: 0.0048 - val_psnr_metric: 25.5590
# Epoch 3682/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.1011 - val_loss: 0.0059 - val_psnr_metric: 25.9693
# Epoch 3683/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 27.8116 - val_loss: 0.0061 - val_psnr_metric: 25.5196
# Epoch 3684/4000
# 12/12 - 3s - loss: 0.0055 - psnr_metric: 26.8423 - val_loss: 0.0054 - val_psnr_metric: 26.1595
# Epoch 3685/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.4458 - val_loss: 0.0057 - val_psnr_metric: 26.7938
# Epoch 3686/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.5420 - val_loss: 0.0056 - val_psnr_metric: 26.1734
# Epoch 3687/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.5002 - val_loss: 0.0054 - val_psnr_metric: 26.0771
# Epoch 3688/4000
# 12/12 - 3s - loss: 0.0055 - psnr_metric: 27.0867 - val_loss: 0.0054 - val_psnr_metric: 25.4292
# Epoch 3689/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.0440 - val_loss: 0.0058 - val_psnr_metric: 25.7630
# Epoch 3690/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.0612 - val_loss: 0.0057 - val_psnr_metric: 25.6078
# Epoch 3691/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.1536 - val_loss: 0.0046 - val_psnr_metric: 26.8946
# Epoch 3692/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.3435 - val_loss: 0.0060 - val_psnr_metric: 25.5644
# Epoch 3693/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 28.0844 - val_loss: 0.0042 - val_psnr_metric: 26.5040
# Epoch 3694/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.4456 - val_loss: 0.0049 - val_psnr_metric: 26.3115
# Epoch 3695/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 27.6963 - val_loss: 0.0056 - val_psnr_metric: 25.7704
# Epoch 3696/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 27.1485 - val_loss: 0.0044 - val_psnr_metric: 27.4012
# Epoch 3697/4000
# Epoch 3698/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.2934 - val_loss: 0.0058 - val_psnr_metric: 25.3563
# Epoch 3699/4000
# 12/12 - 3s - loss: 0.0057 - psnr_metric: 27.1217 - val_loss: 0.0058 - val_psnr_metric: 25.4653
# Epoch 3700/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.6795 - val_loss: 0.0056 - val_psnr_metric: 25.3595
# Epoch 3701/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.2312 - val_loss: 0.0049 - val_psnr_metric: 26.4109
# Epoch 3702/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 26.6923 - val_loss: 0.0059 - val_psnr_metric: 26.2694
# Epoch 3703/4000
# 12/12 - 3s - loss: 0.0041 - psnr_metric: 28.1343 - val_loss: 0.0063 - val_psnr_metric: 25.4813
# Epoch 3704/4000
# 12/12 - 4s - loss: 0.0048 - psnr_metric: 27.3738 - val_loss: 0.0053 - val_psnr_metric: 26.4269
# Epoch 3706/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.6576 - val_loss: 0.0054 - val_psnr_metric: 26.8920
# Epoch 3707/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.3080 - val_loss: 0.0050 - val_psnr_metric: 26.0821
# Epoch 3708/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 26.9408 - val_loss: 0.0060 - val_psnr_metric: 25.8267
# Epoch 3709/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.2264 - val_loss: 0.0062 - val_psnr_metric: 25.1688
# Epoch 3710/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 27.1509 - val_loss: 0.0049 - val_psnr_metric: 26.7817
# Epoch 3711/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.4903 - val_loss: 0.0054 - val_psnr_metric: 26.4193
# Epoch 3712/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 26.7723 - val_loss: 0.0044 - val_psnr_metric: 26.8582
# Epoch 3713/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 26.7465 - val_loss: 0.0055 - val_psnr_metric: 26.1624
# Epoch 3714/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 27.0951 - val_loss: 0.0064 - val_psnr_metric: 24.3304
# Epoch 3715/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 26.7112 - val_loss: 0.0058 - val_psnr_metric: 25.4962
# Epoch 3716/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.6991 - val_loss: 0.0061 - val_psnr_metric: 25.4403
# Epoch 3717/4000
# 12/12 - 3s - loss: 0.0054 - psnr_metric: 26.4754 - val_loss: 0.0056 - val_psnr_metric: 26.2355
# Epoch 3718/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 26.5538 - val_loss: 0.0054 - val_psnr_metric: 26.7354
# Epoch 3719/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 26.5772 - val_loss: 0.0058 - val_psnr_metric: 25.3994
# Epoch 3720/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.4058 - val_loss: 0.0049 - val_psnr_metric: 26.6762
# Epoch 3721/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 26.3884 - val_loss: 0.0053 - val_psnr_metric: 26.1935
# Epoch 3722/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.8422 - val_loss: 0.0054 - val_psnr_metric: 26.3389
# Epoch 3723/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.1370 - val_loss: 0.0058 - val_psnr_metric: 25.6838
# Epoch 3724/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 27.9573 - val_loss: 0.0055 - val_psnr_metric: 26.2412
# Epoch 3725/4000
# 12/12 - 3s - loss: 0.0055 - psnr_metric: 26.8540 - val_loss: 0.0053 - val_psnr_metric: 26.5229
# Epoch 3726/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.4199 - val_loss: 0.0044 - val_psnr_metric: 27.3551
# Epoch 3727/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.7699 - val_loss: 0.0052 - val_psnr_metric: 26.8081
# Epoch 3728/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.9093 - val_loss: 0.0050 - val_psnr_metric: 26.1306
# Epoch 3729/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.5626 - val_loss: 0.0057 - val_psnr_metric: 25.8289
# Epoch 3730/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.7072 - val_loss: 0.0046 - val_psnr_metric: 26.6818
# Epoch 3731/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.9582 - val_loss: 0.0056 - val_psnr_metric: 25.4239
# Epoch 3732/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.3127 - val_loss: 0.0051 - val_psnr_metric: 26.3928
# Epoch 3733/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.7582 - val_loss: 0.0059 - val_psnr_metric: 25.3188
# Epoch 3734/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.7701 - val_loss: 0.0054 - val_psnr_metric: 26.1566
# Epoch 3735/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.5287 - val_loss: 0.0052 - val_psnr_metric: 25.6151
# Epoch 3736/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.8265 - val_loss: 0.0053 - val_psnr_metric: 26.5282
# Epoch 3737/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.4749 - val_loss: 0.0046 - val_psnr_metric: 26.8234
# Epoch 3738/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.2423 - val_loss: 0.0063 - val_psnr_metric: 25.6198
# Epoch 3739/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 27.6142 - val_loss: 0.0045 - val_psnr_metric: 26.4611
# Epoch 3740/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.7629 - val_loss: 0.0047 - val_psnr_metric: 26.2747
# Epoch 3741/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 26.2965 - val_loss: 0.0048 - val_psnr_metric: 27.1117
# Epoch 3742/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.2227 - val_loss: 0.0063 - val_psnr_metric: 25.4928
# Epoch 3743/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.2902 - val_loss: 0.0053 - val_psnr_metric: 26.1084
# Epoch 3744/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 27.0086 - val_loss: 0.0050 - val_psnr_metric: 26.1818
# Epoch 3745/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.2016 - val_loss: 0.0046 - val_psnr_metric: 26.3669
# Epoch 3746/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 26.8045 - val_loss: 0.0062 - val_psnr_metric: 25.3711
# Epoch 3747/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.2942 - val_loss: 0.0053 - val_psnr_metric: 26.7711
# Epoch 3748/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.2403 - val_loss: 0.0052 - val_psnr_metric: 25.6385
# Epoch 3749/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.6088 - val_loss: 0.0053 - val_psnr_metric: 25.2330
# Epoch 3750/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.1933 - val_loss: 0.0056 - val_psnr_metric: 25.8614
# Epoch 3751/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 27.0378 - val_loss: 0.0051 - val_psnr_metric: 25.5111
# Epoch 3752/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.1496 - val_loss: 0.0055 - val_psnr_metric: 25.3557
# Epoch 3753/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 26.9133 - val_loss: 0.0049 - val_psnr_metric: 27.0173
# Epoch 3754/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.8801 - val_loss: 0.0056 - val_psnr_metric: 26.4356
# Epoch 3755/4000
# 12/12 - 3s - loss: 0.0057 - psnr_metric: 26.4010 - val_loss: 0.0058 - val_psnr_metric: 26.2776
# Epoch 3756/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 27.9676 - val_loss: 0.0059 - val_psnr_metric: 24.8029
# Epoch 3757/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.5952 - val_loss: 0.0055 - val_psnr_metric: 25.6984
# Epoch 3758/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 26.4262 - val_loss: 0.0055 - val_psnr_metric: 26.2102
# Epoch 3759/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.3657 - val_loss: 0.0056 - val_psnr_metric: 26.2832
# Epoch 3760/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 26.9334 - val_loss: 0.0060 - val_psnr_metric: 25.7689
# Epoch 3761/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 26.8695 - val_loss: 0.0059 - val_psnr_metric: 26.5866
# Epoch 3762/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 26.7098 - val_loss: 0.0055 - val_psnr_metric: 25.6572
# Epoch 3763/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.6521 - val_loss: 0.0060 - val_psnr_metric: 25.2854
# Epoch 3764/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.3381 - val_loss: 0.0044 - val_psnr_metric: 26.9633
# Epoch 3765/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.3978 - val_loss: 0.0060 - val_psnr_metric: 26.2401
# Epoch 3766/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 26.9918 - val_loss: 0.0049 - val_psnr_metric: 26.4455
# Epoch 3767/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.6952 - val_loss: 0.0056 - val_psnr_metric: 26.3394
# Epoch 3768/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.5977 - val_loss: 0.0066 - val_psnr_metric: 25.3097
# Epoch 3769/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.3005 - val_loss: 0.0053 - val_psnr_metric: 26.6141
# Epoch 3770/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 27.7211 - val_loss: 0.0048 - val_psnr_metric: 26.9837
# Epoch 3771/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 28.0475 - val_loss: 0.0048 - val_psnr_metric: 26.5325
# Epoch 3772/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 27.1191 - val_loss: 0.0054 - val_psnr_metric: 25.8730
# Epoch 3773/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.7951 - val_loss: 0.0054 - val_psnr_metric: 25.5037
# Epoch 3774/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.2660 - val_loss: 0.0052 - val_psnr_metric: 25.8830
# Epoch 3775/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.2607 - val_loss: 0.0055 - val_psnr_metric: 26.3214
# Epoch 3776/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.5260 - val_loss: 0.0053 - val_psnr_metric: 25.9192
# Epoch 3777/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.7355 - val_loss: 0.0049 - val_psnr_metric: 26.2336
# Epoch 3778/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.6978 - val_loss: 0.0055 - val_psnr_metric: 25.8940
# Epoch 3779/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 27.5204 - val_loss: 0.0057 - val_psnr_metric: 26.0243
# Epoch 3780/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 26.3387 - val_loss: 0.0055 - val_psnr_metric: 26.1987
# Epoch 3781/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 26.7491 - val_loss: 0.0056 - val_psnr_metric: 25.7406
# Epoch 3782/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.4691 - val_loss: 0.0047 - val_psnr_metric: 26.3661
# Epoch 3783/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.0776 - val_loss: 0.0058 - val_psnr_metric: 25.9034
# Epoch 3784/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.8497 - val_loss: 0.0052 - val_psnr_metric: 25.8550
# Epoch 3785/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 28.3879 - val_loss: 0.0053 - val_psnr_metric: 26.5075
# Epoch 3786/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.4831 - val_loss: 0.0053 - val_psnr_metric: 26.4142
# Epoch 3787/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 26.0470 - val_loss: 0.0060 - val_psnr_metric: 25.5262
# Epoch 3788/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.6449 - val_loss: 0.0061 - val_psnr_metric: 25.8672
# Epoch 3789/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.6054 - val_loss: 0.0049 - val_psnr_metric: 26.2836
# Epoch 3790/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.0369 - val_loss: 0.0055 - val_psnr_metric: 26.3299
# Epoch 3791/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.2385 - val_loss: 0.0055 - val_psnr_metric: 24.9802
# Epoch 3792/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 27.0553 - val_loss: 0.0060 - val_psnr_metric: 25.5420
# Epoch 3793/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 26.9380 - val_loss: 0.0057 - val_psnr_metric: 25.7940
# Epoch 3794/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.2079 - val_loss: 0.0050 - val_psnr_metric: 25.9868
# Epoch 3795/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.8046 - val_loss: 0.0050 - val_psnr_metric: 26.9255
# Epoch 3796/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.9873 - val_loss: 0.0044 - val_psnr_metric: 26.5329
# Epoch 3797/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 27.4819 - val_loss: 0.0051 - val_psnr_metric: 26.2888
# Epoch 3798/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.8976 - val_loss: 0.0056 - val_psnr_metric: 26.6820
# Epoch 3799/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.4012 - val_loss: 0.0054 - val_psnr_metric: 25.8330
# Epoch 3800/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.7014 - val_loss: 0.0052 - val_psnr_metric: 26.4059
# Epoch 3801/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 26.8624 - val_loss: 0.0045 - val_psnr_metric: 26.9023
# Epoch 3802/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.5135 - val_loss: 0.0047 - val_psnr_metric: 26.1466
# Epoch 3803/4000
# 12/12 - 3s - loss: 0.0058 - psnr_metric: 26.3453 - val_loss: 0.0053 - val_psnr_metric: 25.5788
# Epoch 3804/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.8404 - val_loss: 0.0051 - val_psnr_metric: 26.5920
# Epoch 3805/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.7335 - val_loss: 0.0046 - val_psnr_metric: 27.1383
# Epoch 3806/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.9390 - val_loss: 0.0050 - val_psnr_metric: 26.8032
# Epoch 3807/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.0948 - val_loss: 0.0053 - val_psnr_metric: 25.6488
# Epoch 3808/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.3402 - val_loss: 0.0051 - val_psnr_metric: 26.5260
# Epoch 3809/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 26.8746 - val_loss: 0.0058 - val_psnr_metric: 24.9881
# Epoch 3810/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 27.6697 - val_loss: 0.0053 - val_psnr_metric: 26.3941
# Epoch 3811/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.0815 - val_loss: 0.0062 - val_psnr_metric: 25.6054
# Epoch 3812/4000
# 12/12 - 3s - loss: 0.0040 - psnr_metric: 27.5066 - val_loss: 0.0039 - val_psnr_metric: 26.8038
# Epoch 3813/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 27.5898 - val_loss: 0.0049 - val_psnr_metric: 26.3562
# Epoch 3814/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 25.7801 - val_loss: 0.0052 - val_psnr_metric: 26.1208
# Epoch 3815/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.1009 - val_loss: 0.0059 - val_psnr_metric: 26.1327
# Epoch 3816/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.9109 - val_loss: 0.0053 - val_psnr_metric: 25.8623
# Epoch 3817/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.7898 - val_loss: 0.0048 - val_psnr_metric: 26.0382
# Epoch 3818/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.0743 - val_loss: 0.0060 - val_psnr_metric: 25.7262
# Epoch 3819/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.2828 - val_loss: 0.0045 - val_psnr_metric: 27.2964
# Epoch 3820/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.6989 - val_loss: 0.0050 - val_psnr_metric: 26.0609
# Epoch 3821/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 27.1105 - val_loss: 0.0044 - val_psnr_metric: 26.9369
# Epoch 3822/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 27.0970 - val_loss: 0.0053 - val_psnr_metric: 26.2399
# Epoch 3823/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.5895 - val_loss: 0.0053 - val_psnr_metric: 26.3191
# Epoch 3824/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 27.1132 - val_loss: 0.0064 - val_psnr_metric: 25.0751
# Epoch 3825/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 26.8585 - val_loss: 0.0059 - val_psnr_metric: 25.8676
# Epoch 3826/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 26.8859 - val_loss: 0.0048 - val_psnr_metric: 26.0099
# Epoch 3827/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 27.3208 - val_loss: 0.0052 - val_psnr_metric: 26.2041
# Epoch 3828/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 27.9519 - val_loss: 0.0052 - val_psnr_metric: 25.7811
# Epoch 3829/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.7664 - val_loss: 0.0051 - val_psnr_metric: 26.1527
# Epoch 3830/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.7611 - val_loss: 0.0060 - val_psnr_metric: 26.2793
# Epoch 3831/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 27.3842 - val_loss: 0.0060 - val_psnr_metric: 25.0274
# Epoch 3832/4000
# 12/12 - 3s - loss: 0.0054 - psnr_metric: 25.9209 - val_loss: 0.0055 - val_psnr_metric: 26.7574
# Epoch 3833/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 27.6554 - val_loss: 0.0050 - val_psnr_metric: 26.2396
# Epoch 3834/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 28.0355 - val_loss: 0.0051 - val_psnr_metric: 26.0373
# Epoch 3835/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.1895 - val_loss: 0.0054 - val_psnr_metric: 26.4296
# Epoch 3836/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.6527 - val_loss: 0.0047 - val_psnr_metric: 26.6831
# Epoch 3837/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.9595 - val_loss: 0.0050 - val_psnr_metric: 26.0517
# Epoch 3838/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 26.2795 - val_loss: 0.0056 - val_psnr_metric: 25.2213
# Epoch 3839/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.3667 - val_loss: 0.0050 - val_psnr_metric: 26.1712
# Epoch 3840/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.0181 - val_loss: 0.0054 - val_psnr_metric: 26.9088
# Epoch 3841/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.3960 - val_loss: 0.0049 - val_psnr_metric: 25.9567
# Epoch 3842/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.2114 - val_loss: 0.0055 - val_psnr_metric: 25.9689
# Epoch 3843/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.8412 - val_loss: 0.0048 - val_psnr_metric: 26.1387
# Epoch 3844/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 26.8358 - val_loss: 0.0057 - val_psnr_metric: 25.4591
# Epoch 3845/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.5628 - val_loss: 0.0062 - val_psnr_metric: 25.7301
# Epoch 3846/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.4490 - val_loss: 0.0044 - val_psnr_metric: 26.5714
# Epoch 3847/4000
# 12/12 - 3s - loss: 0.0040 - psnr_metric: 27.9528 - val_loss: 0.0051 - val_psnr_metric: 25.7066
# Epoch 3848/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.8563 - val_loss: 0.0064 - val_psnr_metric: 25.3868
# Epoch 3849/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.8835 - val_loss: 0.0061 - val_psnr_metric: 25.4131
# Epoch 3850/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 28.2536 - val_loss: 0.0056 - val_psnr_metric: 26.4288
# Epoch 3851/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 27.3282 - val_loss: 0.0054 - val_psnr_metric: 26.0797
# Epoch 3852/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.4915 - val_loss: 0.0053 - val_psnr_metric: 25.8897
# Epoch 3853/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.5840 - val_loss: 0.0050 - val_psnr_metric: 26.4211
# Epoch 3854/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 26.7278 - val_loss: 0.0055 - val_psnr_metric: 26.3826
# Epoch 3855/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.3095 - val_loss: 0.0046 - val_psnr_metric: 26.7051
# Epoch 3856/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 27.0850 - val_loss: 0.0044 - val_psnr_metric: 26.4377
# Epoch 3857/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 27.1879 - val_loss: 0.0050 - val_psnr_metric: 26.2465
# Epoch 3858/4000
# 12/12 - 3s - loss: 0.0055 - psnr_metric: 26.5682 - val_loss: 0.0058 - val_psnr_metric: 26.0632
# Epoch 3859/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 26.7772 - val_loss: 0.0050 - val_psnr_metric: 26.0852
# Epoch 3860/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.4979 - val_loss: 0.0049 - val_psnr_metric: 26.2608
# Epoch 3861/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.9072 - val_loss: 0.0049 - val_psnr_metric: 26.6475
# Epoch 3862/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.6522 - val_loss: 0.0061 - val_psnr_metric: 25.7691
# Epoch 3863/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.9078 - val_loss: 0.0059 - val_psnr_metric: 25.8706
# Epoch 3864/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 26.1812 - val_loss: 0.0057 - val_psnr_metric: 25.6934
# Epoch 3865/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.4063 - val_loss: 0.0056 - val_psnr_metric: 25.9909
# Epoch 3866/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.1504 - val_loss: 0.0056 - val_psnr_metric: 25.3042
# Epoch 3867/4000
# 12/12 - 3s - loss: 0.0056 - psnr_metric: 26.4535 - val_loss: 0.0056 - val_psnr_metric: 25.5129
# Epoch 3868/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.0785 - val_loss: 0.0052 - val_psnr_metric: 26.4639
# Epoch 3869/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 26.7912 - val_loss: 0.0048 - val_psnr_metric: 26.2093
# Epoch 3870/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.5397 - val_loss: 0.0054 - val_psnr_metric: 25.9900
# Epoch 3871/4000
# 12/12 - 3s - loss: 0.0040 - psnr_metric: 27.9699 - val_loss: 0.0054 - val_psnr_metric: 26.5494
# Epoch 3872/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.7191 - val_loss: 0.0066 - val_psnr_metric: 25.8938
# Epoch 3873/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.6761 - val_loss: 0.0046 - val_psnr_metric: 26.7609
# Epoch 3874/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.0787 - val_loss: 0.0060 - val_psnr_metric: 26.0583
# Epoch 3875/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 26.4281 - val_loss: 0.0048 - val_psnr_metric: 26.0911
# Epoch 3876/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 27.1722 - val_loss: 0.0053 - val_psnr_metric: 26.3796
# Epoch 3877/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 27.8367 - val_loss: 0.0044 - val_psnr_metric: 26.9374
# Epoch 3878/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 27.4721 - val_loss: 0.0046 - val_psnr_metric: 27.0161
# Epoch 3879/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 26.8618 - val_loss: 0.0061 - val_psnr_metric: 25.1074
# Epoch 3880/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 26.8302 - val_loss: 0.0051 - val_psnr_metric: 26.1611
# Epoch 3881/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.0529 - val_loss: 0.0055 - val_psnr_metric: 26.1325
# Epoch 3882/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 28.1360 - val_loss: 0.0045 - val_psnr_metric: 27.2373
# Epoch 3883/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.1414 - val_loss: 0.0046 - val_psnr_metric: 26.4558
# Epoch 3884/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.0716 - val_loss: 0.0057 - val_psnr_metric: 26.1262
# Epoch 3885/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.4657 - val_loss: 0.0055 - val_psnr_metric: 25.7458
# Epoch 3886/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.2418 - val_loss: 0.0043 - val_psnr_metric: 27.0257
# Epoch 3887/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.1925 - val_loss: 0.0055 - val_psnr_metric: 25.7024
# Epoch 3888/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 26.6684 - val_loss: 0.0047 - val_psnr_metric: 26.6967
# Epoch 3889/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.8925 - val_loss: 0.0057 - val_psnr_metric: 25.7885
# Epoch 3890/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 26.8138 - val_loss: 0.0052 - val_psnr_metric: 25.8275
# Epoch 3891/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 27.6746 - val_loss: 0.0056 - val_psnr_metric: 25.8288
# Epoch 3892/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.5631 - val_loss: 0.0050 - val_psnr_metric: 26.0272
# Epoch 3893/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 26.8258 - val_loss: 0.0051 - val_psnr_metric: 26.9105
# Epoch 3894/4000
# 12/12 - 3s - loss: 0.0055 - psnr_metric: 26.2209 - val_loss: 0.0064 - val_psnr_metric: 25.5553
# Epoch 3895/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 27.7135 - val_loss: 0.0055 - val_psnr_metric: 26.1472
# Epoch 3896/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.0874 - val_loss: 0.0052 - val_psnr_metric: 25.7794
# Epoch 3897/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 26.8070 - val_loss: 0.0047 - val_psnr_metric: 26.8952
# Epoch 3898/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 27.3928 - val_loss: 0.0056 - val_psnr_metric: 26.2072
# Epoch 3899/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 27.5620 - val_loss: 0.0054 - val_psnr_metric: 26.6410
# Epoch 3900/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 26.3930 - val_loss: 0.0057 - val_psnr_metric: 25.7507
# Epoch 3901/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.0967 - val_loss: 0.0050 - val_psnr_metric: 26.1492
# Epoch 3902/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.1343 - val_loss: 0.0051 - val_psnr_metric: 26.1943
# Epoch 3903/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 27.1888 - val_loss: 0.0064 - val_psnr_metric: 25.0276
# Epoch 3904/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.2270 - val_loss: 0.0053 - val_psnr_metric: 26.3740
# Epoch 3905/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 26.8300 - val_loss: 0.0057 - val_psnr_metric: 25.0847
# Epoch 3906/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 28.0456 - val_loss: 0.0050 - val_psnr_metric: 26.4712
# Epoch 3907/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 26.9859 - val_loss: 0.0051 - val_psnr_metric: 26.2077
# Epoch 3908/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.2168 - val_loss: 0.0052 - val_psnr_metric: 26.1564
# Epoch 3909/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.4521 - val_loss: 0.0049 - val_psnr_metric: 26.1235
# Epoch 3910/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.3059 - val_loss: 0.0049 - val_psnr_metric: 26.7845
# Epoch 3911/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.4521 - val_loss: 0.0049 - val_psnr_metric: 26.6741
# Epoch 3912/4000
# 12/12 - 3s - loss: 0.0054 - psnr_metric: 26.4307 - val_loss: 0.0045 - val_psnr_metric: 26.7929
# Epoch 3913/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 27.5819 - val_loss: 0.0050 - val_psnr_metric: 25.9123
# Epoch 3914/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 27.2479 - val_loss: 0.0054 - val_psnr_metric: 25.7356
# Epoch 3915/4000
# 12/12 - 3s - loss: 0.0053 - psnr_metric: 26.7447 - val_loss: 0.0047 - val_psnr_metric: 26.7175
# Epoch 3916/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 27.5648 - val_loss: 0.0049 - val_psnr_metric: 26.4110
# Epoch 3917/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 27.0447 - val_loss: 0.0051 - val_psnr_metric: 26.0745
# Epoch 3918/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.5604 - val_loss: 0.0049 - val_psnr_metric: 25.9568
# Epoch 3919/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.5267 - val_loss: 0.0054 - val_psnr_metric: 25.9540
# Epoch 3920/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.6250 - val_loss: 0.0054 - val_psnr_metric: 26.5083
# Epoch 3921/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.1002 - val_loss: 0.0047 - val_psnr_metric: 26.6786
# Epoch 3922/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.9480 - val_loss: 0.0046 - val_psnr_metric: 26.4730
# Epoch 3923/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 26.3665 - val_loss: 0.0050 - val_psnr_metric: 26.5783
# Epoch 3924/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 27.0747 - val_loss: 0.0045 - val_psnr_metric: 26.6854
# Epoch 3925/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 27.4584 - val_loss: 0.0070 - val_psnr_metric: 25.1617
# Epoch 3926/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.7547 - val_loss: 0.0052 - val_psnr_metric: 26.0999
# Epoch 3927/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.4211 - val_loss: 0.0046 - val_psnr_metric: 26.6203
# Epoch 3928/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.4261 - val_loss: 0.0056 - val_psnr_metric: 25.9961
# Epoch 3929/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.3519 - val_loss: 0.0054 - val_psnr_metric: 26.5898
# Epoch 3930/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 27.1339 - val_loss: 0.0046 - val_psnr_metric: 26.6398
# Epoch 3931/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 27.2401 - val_loss: 0.0044 - val_psnr_metric: 26.7869
# Epoch 3932/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 26.3456 - val_loss: 0.0050 - val_psnr_metric: 26.1885
# Epoch 3933/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.9769 - val_loss: 0.0056 - val_psnr_metric: 26.3206
# Epoch 3934/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.0435 - val_loss: 0.0055 - val_psnr_metric: 26.0943
# Epoch 3935/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.6494 - val_loss: 0.0063 - val_psnr_metric: 25.2572
# Epoch 3936/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.6982 - val_loss: 0.0046 - val_psnr_metric: 27.3798
# Epoch 3937/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.9922 - val_loss: 0.0052 - val_psnr_metric: 26.0784
# Epoch 3938/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 26.4247 - val_loss: 0.0048 - val_psnr_metric: 26.2681
# Epoch 3939/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.6487 - val_loss: 0.0050 - val_psnr_metric: 26.1685
# Epoch 3940/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 27.2339 - val_loss: 0.0049 - val_psnr_metric: 26.6403
# Epoch 3941/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.3458 - val_loss: 0.0057 - val_psnr_metric: 25.7876
# Epoch 3942/4000
# 12/12 - 3s - loss: 0.0054 - psnr_metric: 27.1510 - val_loss: 0.0057 - val_psnr_metric: 25.9095
# Epoch 3943/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.4016 - val_loss: 0.0051 - val_psnr_metric: 26.7650
# Epoch 3944/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.6698 - val_loss: 0.0049 - val_psnr_metric: 26.6310
# Epoch 3945/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 26.9186 - val_loss: 0.0059 - val_psnr_metric: 26.0132
# Epoch 3946/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 27.4712 - val_loss: 0.0050 - val_psnr_metric: 26.2204
# Epoch 3947/4000
# 12/12 - 3s - loss: 0.0054 - psnr_metric: 27.3298 - val_loss: 0.0049 - val_psnr_metric: 26.1488
# Epoch 3948/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 27.6297 - val_loss: 0.0049 - val_psnr_metric: 26.1533
# Epoch 3949/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.4235 - val_loss: 0.0058 - val_psnr_metric: 25.6239
# Epoch 3950/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 26.8909 - val_loss: 0.0066 - val_psnr_metric: 25.3444
# Epoch 3951/4000
# 12/12 - 3s - loss: 0.0055 - psnr_metric: 26.6485 - val_loss: 0.0055 - val_psnr_metric: 25.9648
# Epoch 3952/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.9959 - val_loss: 0.0054 - val_psnr_metric: 25.8251
# Epoch 3953/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 27.4437 - val_loss: 0.0047 - val_psnr_metric: 26.2833
# Epoch 3954/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 26.7464 - val_loss: 0.0045 - val_psnr_metric: 26.9358
# Epoch 3955/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 27.7872 - val_loss: 0.0060 - val_psnr_metric: 25.6165
# Epoch 3956/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 26.5940 - val_loss: 0.0053 - val_psnr_metric: 25.4514
# Epoch 3957/4000
# 12/12 - 3s - loss: 0.0042 - psnr_metric: 27.5518 - val_loss: 0.0048 - val_psnr_metric: 26.4370
# Epoch 3958/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.5469 - val_loss: 0.0058 - val_psnr_metric: 26.3830
# Epoch 3959/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 26.5678 - val_loss: 0.0055 - val_psnr_metric: 25.6686
# Epoch 3960/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.6635 - val_loss: 0.0052 - val_psnr_metric: 26.3875
# Epoch 3961/4000
# 12/12 - 3s - loss: 0.0055 - psnr_metric: 26.5339 - val_loss: 0.0046 - val_psnr_metric: 27.3440
# Epoch 3962/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.0477 - val_loss: 0.0051 - val_psnr_metric: 26.9721
# Epoch 3963/4000
# 12/12 - 3s - loss: 0.0060 - psnr_metric: 26.0940 - val_loss: 0.0052 - val_psnr_metric: 25.5522
# Epoch 3964/4000
# 12/12 - 3s - loss: 0.0050 - psnr_metric: 26.6165 - val_loss: 0.0051 - val_psnr_metric: 25.7941
# Epoch 3965/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.0408 - val_loss: 0.0059 - val_psnr_metric: 25.8849
# Epoch 3966/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.1192 - val_loss: 0.0050 - val_psnr_metric: 25.9381
# Epoch 3967/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 28.0011 - val_loss: 0.0051 - val_psnr_metric: 26.1436
# Epoch 3968/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 27.2946 - val_loss: 0.0052 - val_psnr_metric: 26.2905
# Epoch 3969/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 27.5931 - val_loss: 0.0048 - val_psnr_metric: 26.0560
# Epoch 3970/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 26.7557 - val_loss: 0.0051 - val_psnr_metric: 26.4870
# Epoch 3971/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 27.1618 - val_loss: 0.0057 - val_psnr_metric: 25.6894
# Epoch 3972/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 26.5053 - val_loss: 0.0051 - val_psnr_metric: 26.4469
# Epoch 3973/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 28.2887 - val_loss: 0.0057 - val_psnr_metric: 25.4658
# Epoch 3974/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 26.7082 - val_loss: 0.0062 - val_psnr_metric: 25.0263
# Epoch 3975/4000
# 12/12 - 3s - loss: 0.0047 - psnr_metric: 27.1234 - val_loss: 0.0052 - val_psnr_metric: 26.3457
# Epoch 3976/4000
# 12/12 - 3s - loss: 0.0055 - psnr_metric: 26.1743 - val_loss: 0.0045 - val_psnr_metric: 26.7933
# Epoch 3977/4000
# 12/12 - 3s - loss: 0.0041 - psnr_metric: 28.1123 - val_loss: 0.0047 - val_psnr_metric: 26.3157
# Epoch 3978/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 26.4840 - val_loss: 0.0058 - val_psnr_metric: 25.3387
# Epoch 3979/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 27.1646 - val_loss: 0.0055 - val_psnr_metric: 25.4151
# Epoch 3980/4000
# 12/12 - 3s - loss: 0.0044 - psnr_metric: 27.0725 - val_loss: 0.0051 - val_psnr_metric: 27.2004
# Epoch 3981/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.4130 - val_loss: 0.0054 - val_psnr_metric: 25.5949
# Epoch 3982/4000
# 12/12 - 3s - loss: 0.0051 - psnr_metric: 26.5924 - val_loss: 0.0051 - val_psnr_metric: 26.5321
# Epoch 3983/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.2116 - val_loss: 0.0055 - val_psnr_metric: 26.1525
# Epoch 3984/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.0557 - val_loss: 0.0055 - val_psnr_metric: 26.1307
# Epoch 3985/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 26.8545 - val_loss: 0.0052 - val_psnr_metric: 26.7791
# Epoch 3986/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 27.1551 - val_loss: 0.0057 - val_psnr_metric: 25.3586
# Epoch 3987/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.3149 - val_loss: 0.0057 - val_psnr_metric: 25.7450
# Epoch 3988/4000
# 12/12 - 3s - loss: 0.0049 - psnr_metric: 27.1863 - val_loss: 0.0057 - val_psnr_metric: 25.8607
# Epoch 3989/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 28.0481 - val_loss: 0.0049 - val_psnr_metric: 26.7926
# Epoch 3990/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 26.1606 - val_loss: 0.0048 - val_psnr_metric: 26.3358
# Epoch 3991/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.5772 - val_loss: 0.0064 - val_psnr_metric: 25.5275
# Epoch 3992/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.3613 - val_loss: 0.0055 - val_psnr_metric: 26.0468
# Epoch 3993/4000
# 12/12 - 3s - loss: 0.0052 - psnr_metric: 26.9326 - val_loss: 0.0051 - val_psnr_metric: 26.8409
# Epoch 3994/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.4907 - val_loss: 0.0059 - val_psnr_metric: 25.4597
# Epoch 3995/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.8331 - val_loss: 0.0050 - val_psnr_metric: 25.9540
# Epoch 3996/4000
# 12/12 - 3s - loss: 0.0043 - psnr_metric: 27.2618 - val_loss: 0.0046 - val_psnr_metric: 26.4414
# Epoch 3997/4000
# 12/12 - 3s - loss: 0.0045 - psnr_metric: 26.9236 - val_loss: 0.0046 - val_psnr_metric: 26.2302
# Epoch 3998/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.1445 - val_loss: 0.0053 - val_psnr_metric: 25.4622
# Epoch 3999/4000
# 12/12 - 3s - loss: 0.0048 - psnr_metric: 26.8295 - val_loss: 0.0055 - val_psnr_metric: 25.5176
# Epoch 4000/4000
# 12/12 - 3s - loss: 0.0046 - psnr_metric: 27.5956 - val_loss: 0.0048 - val_psnr_metric: 27.2664

# %% [markdown]
# - 이미지 보강으로 데이터가 4배 정도 늘어난 것과 같은 효과이기 때문에 에포크를 1,000에서 4,000으로 늘렸씁니다.
# - `Set5`의 나비 이미지를 테스트해보면 다음과 같은 결과가 나옵니다.

# %% [markdown]
# ### (13) 학습 결과 확인 및 `Set5` 이미지 시각화

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['psnr_metric'], 'b-', label='psnr')
plt.plot(history.history['val_psnr_metric'], 'r--', label='val_psnr')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
image_path = tf.keras.utils.get_file('butterfly.png', 'http://bit.ly/2oAOxgH')
img = tf.io.read_file(image_path)
img = tf.image.decode_jpeg(img, channels=3)
hr = tf.image.convert_image_dtype(img, tf.float32)

lr = tf.image.resize(hr, [hr.shape[0]//4, hr.shape[1]//4])
lr = tf.image.resize(lr, [hr.shape[0], hr.shape[1]])
predict_hr = model.predict(np.expand_dims(lr, axis=0))

print(tf.image.psnr(np.squeeze(predict_hr, axis=0), hr, max_val=1.0))
print(tf.image.psnr(lr, hr, max_val=1.0))


plt.figure(figsize=(16,6))
plt.subplot(1, 3, 1)
plt.imshow(hr)
plt.title('original - hr')

plt.subplot(1, 3, 2)
plt.imshow(lr)
plt.title('lr')

plt.subplot(1, 3, 3)
plt.imshow(np.squeeze(predict_hr, axis=0))
plt.title('sr')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tf.Tensor(22.349665, shape=(), dtype=float32)
# tf.Tensor(20.217585, shape=(), dtype=float32)
# Text(0.5, 1.0, 'sr')

# %% [markdown]
# - 이미지를 불러온 다음 각 이미지에 대한 저해상도 버전과 복원 이미지의 `PSNR` 점수를 구해서 평균을 비교합니다.

# %%
image_path = tf.keras.utils.get_file('/content/Set5.zip', 'http://bit.ly/2MEG4kr')
# !unzip Set5.zip
# Out:
# Downloading data from http://bit.ly/2MEG4kr
# 860160/852576 [==============================] - 0s 0us/step
# Archive:  Set5.zip
#    creating: Set5/
#  extracting: Set5/baby.png
#  extracting: Set5/bird.png
#  extracting: Set5/butterfly.png
#  extracting: Set5/head.png
#   inflating: Set5/woman.png

# %%
set5_image_root = pathlib.Path('/content/Set5')
set5_image_paths = list(set5_image_root.glob('*.*'))

sr_psnr = []
lr_psnr = []

for image_path in set5_image_paths:
    img = tf.io.read_file(str(image_path))
    img = tf.image.decode_jpeg(img, channels=3)
    hr = tf.image.convert_image_dtype(img, tf.float32)

    lr = tf.image.resize(hr, [hr.shape[0]//4, hr.shape[1]//4])
    lr = tf.image.resize(lr, [hr.shape[0], hr.shape[1]])
    predict_hr = model.predict(np.expand_dims(lr, axis=0))
    
    sr_psnr.append(tf.image.psnr(np.squeeze(predict_hr, axis=0), hr, max_val=1.0).numpy())
    lr_psnr.append(tf.image.psnr(lr, hr, max_val=1.0).numpy())
    
print('sr:', sr_psnr)
print('sr mean:', np.mean(sr_psnr))
print()
print('lr:', lr_psnr)
print('lr mean:', np.mean(lr_psnr))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fc446f63158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# sr: [28.628256, 22.349665, 25.808668, 27.925306, 30.419857]
# sr mean: 27.026352
#
# lr: [28.569517, 20.217585, 24.495182, 27.31659, 29.72251]
# lr mean: 26.064276

# %% [markdown]
# - 복원 이미지의 `PSNR` 점수가 저해상도 버전보다 전반적으로 높게 나타나는 것을 확인할 수 있습니다.
# - 4배 확대 초해상도에 대한 벤치마크 사이트에서 `REDNet-30`은 `Set5` 이미지에 대해 최고 31.51점의 `PSNR`점수를 기록하고 있습니다.
# - 학습을 시킬수록 `PSNR` 점수는 증가하는 경향을 보이기 때문에 과적합되지 않을 정도로 충분한 에포크 동안 학습시키고 입력 이미지를 다양하게 만들어서 더 좋은 `PSNR`점수를 얻을 수 있을 겁니다.

# %% [markdown]
# ## III. 연습 파일
# - [구글 Colab에서 직접 연습해보자](https://colab.research.google.com/github/chloevan/deeplearningAI/blob/master/tensorflow2.0/ch9_4_super_resolution.ipynb)

# %% [markdown]
# [^1]: X. Mao, C. Shen, and Y. Yang. (2016, September 1). Image Restoration Using Very Deep Convolutional Encoder-Decoder Networks with Symmetric Skip Connections. Retrieved from https://arxiv.org/abs/1603.09056
#
# ## VI. Reference
#
# 김환희. (2020). 시작하세요! 텐서플로 2.0 프로그래밍: 기초 이론부터 실전 예제까지 한번에 끝내는 머신러닝, 딥러닝 핵심 가이드. 서울: 위키북스.
